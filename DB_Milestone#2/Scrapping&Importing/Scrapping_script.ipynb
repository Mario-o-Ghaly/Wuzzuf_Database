# %%
import requests as rq
import pandas as pd
from bs4 import BeautifulSoup as bsp
from selenium import webdriver

import re
import time
from datetime import datetime
from dateutil.relativedelta import relativedelta

# %%
# for testing
browser = webdriver.Chrome()
browser.get("https://wuzzuf.net/jobs/careers/Nakheel-Egypt-85138")
html_content = browser.page_source
jsoup = bsp(html_content, "html.parser")
browser.quit()

# %%
def nullify(test):
    if re.compile(r'\b\s*not specified\s*\b', re.IGNORECASE).search(test) or re.compile(r'\b\s*confidential\s*\b', re.IGNORECASE).search(test):
        return True
    return False

# %%
def get_title(soup):
    title = soup.find("h1", class_ = "css-f9uh36")
    return title.text

# %%
def get_description(soup):
    description = soup.select(".css-ghicub > .css-1uobp1k")
    description = re.sub(r'([a-z,.,:])([A-Z])', r'\1 \2', description[0].text)
    return description

# %%
def get_requirements(soup):
    reqs = soup.select(".css-ghicub > .css-1t5f0fr")  #css-1t5f0fr
    if len(reqs)>0:
        reqs = re.sub(r'([a-z,.,:])([A-Z])', r'\1 \2', reqs[0].text)
        return reqs
    return None
#     if len(reqs)>0:
#         return reqs[0].text
#     return None
#     if len(reqs):
#         listings = reqs[0].find_all('li')
#         if len(listings):
#             requirements = ""
#             for req in listings:
#                 requirements += "\n" + req.text
#             return requirements[1:]
#         else:
#             listings = reqs[0].find_all("p")
#             if len(listings):
#                 requirements = ""
#                 for req in listings:
#                     requirements += "\n" + req.text
#                 return requirements[1:]
#     else:
#         return None
print(get_requirements(jsoup))

# %%
def get_date(soup):  # it has to exist
    jdate = soup.find("span", class_ = "css-182mrdn")
    date = jdate.text.split(' ')
    current_date = datetime.now()
    if date[2] in ('minute', 'minutes', 'hour', 'hours'):
        posted_date = current_date
    elif date[2] == 'day' or date[2] == 'days':
        posted_date = current_date - relativedelta(days=int(date[1]))
    else:
        posted_date = current_date - relativedelta(months = int(date[1]))
    
    return posted_date.strftime('%Y-%m-%d')

# %%
def get_views(soup):
    views = soup.find_all(class_ = "css-bs44nc")
    if len(views):
        return (int(views[0].text), int(views[1].text))
    else:
        return (None, None)

# %%
def get_details(soup):
    details = soup.select(".css-47jx3m > .css-4xky9y")
    # experience
    
    pattern = r'\s*\d+\s*' #this is a number
    
    # Loop through the list of strings and extract numbers
    for s in details[0]:
        match = re.search(pattern, s)
        if match:
            number_str = match.group().strip()  # Remove leading/trailing spaces
            number = int(number_str)
            break
    
    if nullify(details[0].text):
        experience_min = None
        experience_max = None
    else:
        exp = details[0].text.split(' ')
        pattern = r'\s*\d+\s*'
        
        numbers = []

        for s in exp:
            match = re.search(pattern, s)
            if match:
                number_str = match.group().strip()  # Remove leading/trailing spaces
                number = int(number_str)
                numbers.append(number)
        if len(numbers) > 1:  
            experience_min = int(exp[0])
            experience_max = int(exp[2])
        elif re.compile(r'\b\s*more\s*\b', re.IGNORECASE).search(exp[0]):
            experience_min = numbers[0]
            experience_max = None
        elif re.compile(r'\b\s*less\s*\b', re.IGNORECASE).search(exp[0]):
            experience_min = None
            experience_max = numbers[0]
        else:
            experience_min = None
            experience_max = None

    # career_level
    career_level = details[1].text
    if nullify(career_level):
        career_level = None
        
    # education_level
    education_level = details[2].text
    if nullify(education_level):
        education_level = None
    
    # gender
    if len(details) == 5:
        if re.compile(r'\b\s*male\s*\b', re.IGNORECASE).search(details[3].text):
            gender = 'M'
        else:
            gender = 'F'
        del details[3]
    else:
        gender = None
        
    
    # salary
    salary = details[3].text
    if nullify(salary):
        salary_min = None
        salary_max = None
        hidden_salary = True
    else:
        salary = salary.split(' ')
        salary_min = int(salary[0])
        salary_max = int(salary[2])
        hidden_salary = False
    return (experience_min, experience_max, career_level, education_level, salary_min, salary_max, hidden_salary, gender)
get_details(jsoup)

# %%
def get_vacancies(soup):
    vacancies = soup.find("span", class_ = "css-ixb653")
    vacancies = vacancies.text.split(' ')
    
    # Regular expression pattern to match integers with optional leading/trailing spaces
    pattern = r'\s*\d+\s*'
    
    # Loop through the list of strings and extract numbers
    for s in vacancies:
        match = re.search(pattern, s)
        if match:
            number_str = match.group().strip()  # Remove leading/trailing spaces
            number = int(number_str)
            break
    return number

# %%
def get_company_name(soup):
    company = soup.find('a', class_ = "css-p7pghv")
    if company is None:
        return "Confidential"
    return company.text
print(get_company_name(jsoup))

# %%
# job_posting
def job_posting(jsoup):
    dic={}
#     try:
    job_title = get_title(jsoup)
    dic["job_title"] = job_title
#     print(job_title)

    description = get_description(jsoup)
#     print(description)
    dic["description"] = description

    requirements = get_requirements(jsoup)
#     print(requirements)
    dic["requirements"] = requirements

    post_date = get_date(jsoup)
#     print(post_date)
    dic["post_date"] = post_date

    (viewed, considered) = get_views(jsoup)
    dic["viewed"] = viewed
    dic["considered"] = considered
    (experience_min, experience_max, career_level, education_level, salary_min, salary_max, hidden_salary, gender) = get_details(jsoup)
    # print(experience_min, experience_max, career_level, education_level, salary_min, salary_max, hidden_salary, gender)
    dic["experience_min"] = experience_min
    dic["experience_max"] = experience_max
    dic["career_level"] = career_level
    dic["education_level"] = education_level
    dic["salary_min"] = salary_min
    dic["salary_max"] = salary_max
    dic["hidden_salary"] = hidden_salary
    dic['gender'] = gender

    vacancies = (get_vacancies(jsoup))
#     print(vacancies)
    dic["vacancies"] = vacancies

    company = get_company_name(jsoup)
#     print(company)
    dic["company"] = company
    return dic

# %%
def JPSoup(browser, href):
    browser.get(href)
    html_content = browser.page_source
    jsoup = bsp(html_content, "html.parser")
    return jsoup

# %%
def get_type(soup):
    jtype = soup.find("div", class_ = "css-11rcwxl")
    jtype = jtype.find_all("span", class_ = "css-ja0r8m eoyjyou0")
    return jtype
# print(get_type(jsoup)[0].text)

# %%
def get_category(soup):
    category = soup.find("div", class_ = "css-13sf2ik").find("ul", class_ = "css-h5dsne")
    category = category.find_all("span", class_ = "css-158icaa")
    return category

# %%
def get_skill(soup):
    skill = soup.find("div", class_ = "css-s2o0yh").find_all("a", class_ = "css-g65o95")
    return skill

# %%
def cname(soup):
    company = soup.find('h1', class_ = "css-12s37jy")
    return company.text.strip()
print(cname(jsoup))

# %%
def cprofile(soup):
    profile = soup.find('div', id = 'profile-section').find('div').find_all('span', class_ ="css-1xhj18k")
    attributes = ['Location', 'Founded', 'Industry', 'Company Size']
    data = {}
    sector = []
    for p in profile:
        box = p.select('span')
        att = box[0].text.strip()[:-1]
        if att == 'Location':
            info = box[1].text.strip().split(',')
            country = info[-1].strip()
            if len(info) > 1:
                city = info[-2].strip()
            else:
                city = None
            data['country'] = country
            data['city'] = city
            
        elif att == 'Founded':
            info = box[1].text.strip()
            year = str(info)
            data['found_date'] = year + '-01-01'
            
        elif att == 'Company Size':
            info = box[1].text.split(' ')
            numbers = []
            for i in info:
                match = re.search(r'\s*\d+\s*', i)
                if match:
                    number_str = match.group().strip()  # Remove leading/trailing spaces
                    number = int(number_str)
                    numbers.append(number)
            if len(numbers) > 1:  
                size_min = numbers[0]
                size_max = numbers[1]
            elif re.compile(r'\b\s*more\s*\b', re.IGNORECASE).search(info[0]):
                size_min = numbers[0]
                size_max = None
            elif re.compile(r'\b\s*less\s*\b', re.IGNORECASE).search(info[0]):
                size_min = None
                size_max = numbers[0]
            else:
                size_min = None
                size_max = None
            data['size_min'] = size_min
            data['size_max'] = size_max
        
        elif att == "Industry":
            info = box[1].select('a')
            for i in info:
                sector.append(i.text)
    return (data, sector)
print(cprofile(jsoup))
# Out:
# ({'country': 'Egypt', 'city': 'Cairo', 'found_date': '2008-01-01', 'size_min': None, 'size_max': None}, ['Computer Software', 'Information Technology Services'])

# %%
def cdetails(soup):
    details = soup.find('div', id = 'profile-section')
    if len(details):
        details = details.find('p')
        if details:
            return details.text
    return None
print(cdetails(jsoup))
# Out:
# ICIS is an Information technology company in Cairo/ Egypt and it is a branch of ICIS Company in Riyadh/ Saudi Arabia which serving the Saudi market since 2008,
# It provides enterprise software solutions, IT consulting, Systems Security Management, Data Masking, and many other IT products and services,
# ICIS is the Golden Oracle Partner.

# %%
page_number = 0
concat = ""
page_link = "https://wuzzuf.net/search/jobs/?a=hpb&filters%5Broles%5D%5B0%5D=IT%2FSoftware%20Development&q="
links = set()
link_name = {}
link_name['company'] = 'Confidential'
dic_company = {}
dic_company['company'] = 'Confidential'
dic_sector = {}
errors = []
cerrors = []
terrors = []
caterrors = []
serrors = []

job_posting_data = pd.DataFrame()
job_posting_type_data = pd.DataFrame()
job_posting_category_data = pd.DataFrame()
job_posting_skill_data = pd.DataFrame()

company_data = pd.DataFrame()
company_sector_data = pd.DataFrame()
# fake one for confidential company

for page_number in range(130):
    browser = webdriver.Chrome()
    jobssoup = JPSoup(browser, page_link+concat)
    jobs_locations = jobssoup.select(".css-5wys0k")  
    jobs_links = jobssoup.find_all("h2", class_ = "css-m604qf")


    # jloc = jobs_locations[0]
    # jlink = jobs_links[0]
    # print(jlink, jloc)
    # soup = JPSoup(browser, jlink.a.get('href'))
    # job_title = get_title(soup)
    # print(jsoup.find(class_ = "css-9iujih").find('a').get('href'))

    i = 1
    for jloc, jlink in zip(jobs_locations, jobs_links):
        jloc = jloc.text
        jloc = jloc.split(', ')
        country = jloc[-1][:-1]
        city = jloc[-2]
        if len(jloc) > 2:
            district = jloc[0] 
        else:
            district = "" #NULL

        ##
        print(i)
        print(jlink.a.get('href'))
        links.add(jlink.a.get('href'))
        
        # job_posting_table
        try:
            soup = JPSoup(browser, jlink.a.get('href')) #need to do something with the link
            dic = job_posting(soup)
        except Exception as e:
            print("error in job link: " + jlink.a.get('href'))
            errors.append(jlink.a.get('href'))
            continue
        
        try:
            if dic['company'] != 'Confidential':
                lnk = soup.find(class_ = "css-9iujih").find('a').get('href') #the link of the company
                if lnk not in links:
                    csoup = JPSoup(browser, lnk) #soup for the company
                    company_name = cname(csoup)
                    links.add(lnk) 
                    link_name[lnk] = company_name
                    dic_company['company'] = company_name #or link_name[lnk]
                    dic_company['description'] = cdetails(csoup)
                    company_df = pd.DataFrame(dic_company, index=[0])
                    company_data = pd.concat([company_data, company_df], ignore_index = True)

                    (dic_company, sector) = cprofile(csoup)
                    for s in sector:
                        dic_sector['company'] = company_name #or link_name[lnk]
                        dic_sector['sector'] = s
                        sector_df = pd.DataFrame(dic_sector, index=[0])
                        company_sector_data = pd.concat([company_sector_data, sector_df], ignore_index=True)          


                dic['company'] = link_name[lnk]
        except Exception as ee:
            print("error in company link: " + lnk + "---- when scrapping job link: " + jlink.a.get('href'))
            cerrors.append(lnk)
            continue


        dic['country'] = country
        dic['city'] = city
        dic['district'] = None if district == '' else district

        post_df = pd.DataFrame(dic, index=[0])
        job_posting_data = pd.concat([job_posting_data, post_df], ignore_index=True)


        #job_posting_type
        try:
            
            jtypes = get_type(soup)      
            dic2={}
            dic2['company'] = dic['company'] ## here
            dic2['job_title'] = dic['job_title']
            dic2['country'] = dic['country']
            dic2['city'] = dic['city']
            dic2['district'] = dic['district']
            for jtype in jtypes:
                dic2['job_type'] = jtype.text
                type_df = pd.DataFrame(dic2, index=[0])
                job_posting_type_data = pd.concat([job_posting_type_data, type_df], ignore_index=True)
                
        except Exception as eee:
            print("error in job type with link: " + jlink.a.get('href'))
            terrors.append(jlink.a.get('href'))  


        # job_posting_category
        try:
            del dic2['job_type']
            jcategories = get_category(soup)
            for jcategory in jcategories:
                dic2['job_category'] = jcategory.text
                category_df = pd.DataFrame(dic2, index=[0])
                job_posting_category_data = pd.concat([job_posting_category_data, category_df], ignore_index=True)
            
        except Exception as eeee:
            print("error in job category with link: " + jlink.a.get('href'))
            caterrors.append(jlink.a.get('href'))

        #job_posting_skill
        try:
            del dic2['job_category']
            jskills = get_skill(soup)
            for jskill in jskills:
                dic2['skill'] = jskill.text
                skill_df = pd.DataFrame(dic2, index=[0])
                job_posting_skill_data = pd.concat([job_posting_skill_data, skill_df], ignore_index=True)
        except Exception as eeeee:
            print("error in job skill with link: " + jlink.a.get('href'))
            serrors.append(jlink.a.get('href'))

#         print(dic['company'])
        if i == 15:
            break
        i = i+1
#         time.sleep(3)
    page_number = page_number+1
    concat = "&start="+str(page_number)
    time.sleep(10)



browser.quit()
# Out:
# 1
# https://wuzzuf.net/jobs/p/bwe16Trm8JtM-Full-Stack-Developer-Sketch-tech-Alexandria-Egypt
# 2
# https://wuzzuf.net/jobs/p/360mloRE7C3p-Senior-Backend-Developer-NET-Core-Cairo-Egypt
# 3
# https://wuzzuf.net/jobs/p/B13dTQcyln10-Dot-Net-Web-Developer-Tidal-Cairo-Egypt
# 4
# https://wuzzuf.net/jobs/p/pP71wWVJmrE4-Full-Stack-wordpress-Developer-Osolutions-Cairo-Egypt
# 5
# https://wuzzuf.net/jobs/p/N0Nh5pzRst71-Senior-Odoo-Developer---Onsite-Cairo-Egypt
# 6
# https://wuzzuf.net/jobs/p/9LiqyHcnSQ72-Front-End-Developer-Safa-Soft-Cairo-Egypt
# 7
# https://wuzzuf.net/jobs/p/4xPg2JmGPWEf-IT-Clerk-Nahdet-Misr-Publishing-Group-Giza-Egypt
# 8
# https://wuzzuf.net/jobs/p/YX8Gvbm9KdEk-SAP-SD-CX-function-consultant-Nahdet-Misr-Publishing-Group-Giza-Egypt
# 9
# https://wuzzuf.net/jobs/p/OtBNQ02hxdAW-Senior-Backend-Developer-PHP-iStoria-Cairo-Egypt
# 10
# https://wuzzuf.net/jobs/p/m83efEO24ZYE-UX-Designer-Safa-Soft-Cairo-Egypt
# 11
# https://wuzzuf.net/jobs/p/MU7wIRNPCWqm-C-Qt-Developer-Fruitful-Solutions-Cairo-Egypt
# 12
# https://wuzzuf.net/jobs/p/AKYJxmjs92MV-Software-Development-Team-Leader-Cairo-Egypt
# 13
# https://wuzzuf.net/jobs/p/AZXoq2b4SZKB-Application-Support---Microsoft-dynamic-Ax-Sky-Distribution-Giza-Egypt
# 14
# https://wuzzuf.net/jobs/p/uAeevNoBtaZ3-Senior-IT-Infrastructure-Engineer-Cairo-Egypt
# 15
# https://wuzzuf.net/jobs/p/Eav6dUGzfHAM-Senior-Scrum-Master-Softec-Technologies-Cairo-Egypt
# 1
# https://wuzzuf.net/jobs/p/h2WOBdY96CMM-IT-Sales-Manager-integrated-solutions-Injaz-Tech-for-advanced-systems-Cairo-Egypt
# 2
# https://wuzzuf.net/jobs/p/UPanwkjMPLi7-Developer-Engineer-NET-Giza-Egypt
# 3
# https://wuzzuf.net/jobs/p/Ne6TjHHq36qE-UI-UX-Designer-DX-Republic-Cairo-Egypt
# 4
# https://wuzzuf.net/jobs/p/ohfDr6qvHADZ-Senior-Flutter-Developer-DEVOPSOLUTION-Cairo-Egypt
# 5
# https://wuzzuf.net/jobs/p/bLRIvUvrNx1X-Software-Quality-Assurance-Engineer-Process-Improvement-BI-Technologies-Cairo-Egypt
# 6
# https://wuzzuf.net/jobs/p/SQUROsjBXui2-Senior-NET-Developer-Cairo-Egypt
# 7
# https://wuzzuf.net/jobs/p/42XKveGchgVY-Integration-Engineer-Obeikan-Digital-Solutions-Cairo-Egypt
# 8
# https://wuzzuf.net/jobs/p/LjxofDoad4DT-Senior-Software-Quality-Control-Engineer-Nasr-City-Cairo-Egypt
# 9
# https://wuzzuf.net/jobs/p/Tk2rz9m0xfTQ-Senior-Software-Quality-Engineer-Easy-Cash-Cairo-Egypt
# 10
# https://wuzzuf.net/jobs/p/0PqmIL2OXzh5-Senior-Backend-Developer-PHP-Easy-Cash-Cairo-Egypt
# 11
# https://wuzzuf.net/jobs/p/IY8dHRL38w7V-DevOps-Engineer-Easy-Cash-Cairo-Egypt
# 12
# https://wuzzuf.net/jobs/p/oBNo6tgvm2a4-Senior-Full-Stack-Developer-Angular-and-Java-TRIMETIS-Cairo-Egypt
# 13
# https://wuzzuf.net/jobs/p/qK1NqdC9gSwp-Full-Stack-Team-Lead-Cairo-Egypt
# 14
# https://wuzzuf.net/jobs/p/9vpOQVOLHns4-Senior-Quality-Control-Engineer-Tafeel-Cairo-Egypt
# 15
# https://wuzzuf.net/jobs/p/qiiYOKtd4dLO-IT-Account-Manager-Latalia-Cairo-Egypt
# 1
# https://wuzzuf.net/jobs/p/r6Ic5ENR2Ohk-Sr-Backend-Software-Engineer-FlapKap-Cairo-Egypt
# 2
# https://wuzzuf.net/jobs/p/9cEFFltwu3ND-Senior-Software-Sales-Representative-MakanE-Company-Cairo-Egypt
# 3
# https://wuzzuf.net/jobs/p/P8NFHT7ms33F-Communications-Field-Engineer-JRM-for-Communications-Cairo-Egypt
# 4
# https://wuzzuf.net/jobs/p/pm0ucSd7ka3K-Odoo-Developer-JRM-for-Communications-Cairo-Egypt
# 5
# https://wuzzuf.net/jobs/p/Cfrp4aOcQqPg-Senior-UIUX-Designer-Tafeel-Cairo-Egypt
# 6
# https://wuzzuf.net/jobs/p/LBlze3X9dh4e-3D-Visualizer-Specializing-in-Cinema-4D-Charterhouse-Middle-East-Dubai-United-Arab-Emirates
# 7
# https://wuzzuf.net/jobs/p/sQVvQHfUHHxD-Senior-Analyst-Vendor-Management-–-IT-PMO-Partnerships-flydubai-Dubai-United-Arab-Emirates
# 8
# https://wuzzuf.net/jobs/p/wLk7AZGt1EP4-E--Commerce-APP-Builder-Intern-Veeseven-Child-Protective-Dubai-United-Arab-Emirates
# 9
# https://wuzzuf.net/jobs/p/4t66LjMFVpbv-CRM-Intern-Merck-Sharp-Dohme-Corp-Dubai-United-Arab-Emirates
# 10
# https://wuzzuf.net/jobs/p/bij6E8oUd7AQ-Data-Science-Intern-Merck-Sharp-Dohme-Corp-Dubai-United-Arab-Emirates
# 11
# https://wuzzuf.net/jobs/p/sq2LIAUVgdIO-Senior-Field-Support-Engineer-Trapeze-Dubai-United-Arab-Emirates
# 12
# https://wuzzuf.net/jobs/p/UqpbD2HTub7F-Intern-for-TMCF-Merck-Sharp-Dohme-Corp-Dubai-United-Arab-Emirates
# 13
# https://wuzzuf.net/jobs/p/8rYirE1UKRi8-Data-Analytics-Intern-Merck-Sharp-Dohme-Corp-Dubai-United-Arab-Emirates
# 14
# https://wuzzuf.net/jobs/p/ppNzO37xLjsV-Web-Developer-Merck-Sharp-Dohme-Corp-Dubai-United-Arab-Emirates
# 15
# https://wuzzuf.net/jobs/p/yovY18Ge0TVC-Technical-Support-Engineer-Freelancer-Wicresoft-Cairo-Egypt
# 1
# https://wuzzuf.net/jobs/p/jON8RAfq6Ypt-Server---PenRose-Four-Seasons-Hotels-and-Resorts-Dubai-United-Arab-Emirates
# 2
# https://wuzzuf.net/jobs/p/cTsavszXiBRV-IT-Officer-Giza-Egypt
# 3
# https://wuzzuf.net/jobs/p/kbI5HvTZtcOU-Senior-Software-Sales-Representative-BSmart-Cairo-Egypt
# 4
# https://wuzzuf.net/jobs/p/WbH9CuSg5u12-Senior-Devops-Engineer-Cairo-Egypt
# 5
# https://wuzzuf.net/jobs/p/BCfBYkvbnnyd-Technical-Support-Engineer-Cairo-Egypt
# 6
# https://wuzzuf.net/jobs/p/raGN0guYT9oo-IT-Apps-Delivery-Manager-Cairo-Egypt
# 7
# https://wuzzuf.net/jobs/p/rAyKCJYKo3r3-Business-Analyst-Cairo-Egypt
# 8
# https://wuzzuf.net/jobs/p/YZaTllqno3Gz-Junior-IT-Specialist-Jessour-Misr-Giza-Egypt
# 9
# https://wuzzuf.net/jobs/p/FHTN6KRRfFQM-Senior-Full-Stack-Developer-Horizon-Agency-Cairo-Egypt
# 10
# https://wuzzuf.net/jobs/p/FNjqdHKKk0Vg-WordPress-Developer-Horizon-Agency-Cairo-Egypt
# 11
# https://wuzzuf.net/jobs/p/RusOWp62WQHz-Net-Development-Manager-LINK-Development-Cairo-Egypt
# 12
# https://wuzzuf.net/jobs/p/HNW0aSOEkuZS-IT-Help-Desk-Engineer-Fawry-for-Banking-Technology-and-Electronic-Payments-S-A-E-Giza-Egypt
# 13
# https://wuzzuf.net/jobs/p/fT1XMIEvFie2-Quality-Control-Engineer-Perfect-Presentation-Giza-Egypt
# 14
# https://wuzzuf.net/jobs/p/IBgR4GvAADL4-Scrum-Master-Safa-Soft-Cairo-Egypt
# 15
# https://wuzzuf.net/jobs/p/UpcdfdvqVuOC-Network-Engineer-Cairo-Egypt
# 1
# https://wuzzuf.net/jobs/p/qSIcf5oi3rid-IT-Help-Desk-Technician-Cairo-Egypt
# 2
# https://wuzzuf.net/jobs/p/xkMDRrKdBBdy-Full-Stack-Team-Lead-Net-Angular-ICIS-Cairo-Egypt
# 3
# https://wuzzuf.net/jobs/p/kiMGAYQ5jC3b-Senior-Full-Stack-Developer-Net-Angular-ICIS-Cairo-Egypt
# 4
# https://wuzzuf.net/jobs/p/wLNrSCwpuE1D-Senior-SEO-Senior-Search-Engine-Optimization-PETC-Giza-Egypt
# 5
# https://wuzzuf.net/jobs/p/YAerGTNSWYWM-Senior-Backend-Software-Engineer---Net-Cairo-Egypt
# 6
# https://wuzzuf.net/jobs/p/J9fJSEhsTYAp-Python-Web-Developer---Graduate-Position-Holix-Cairo-Egypt
# 7
# https://wuzzuf.net/jobs/p/Ag8H9SELMLVP-Cyber-Security-ArchitectEngineer-ll-ICSOT-Saudi-National-Only-Honeywell-International-Inc-Riyadh-Saudi-Arabia
# 8
# https://wuzzuf.net/jobs/p/xuhq22TyXTXV-NET-production-Support-Engineer-KSA-Ejada-Riyadh-Saudi-Arabia
# 9
# https://wuzzuf.net/jobs/p/OAyED9TZecEC-DLP-Engineer-ManpowerGroup-Middle-East-Riyadh-Saudi-Arabia
# 10
# https://wuzzuf.net/jobs/p/IawEnx50c0zm-IT-Voice-Administrator-BDO-Esnad-Cairo-Egypt
# 11
# https://wuzzuf.net/jobs/p/5ymDVyNe0qjs-Senior-SEO-Specialist-The-Address-Investments-for-Real-Estate-Consultancy-Cairo-Egypt
# 12
# https://wuzzuf.net/jobs/p/3LxswmFOSE1P-UI-UX-Designer-Cairo-Egypt
# 13
# https://wuzzuf.net/jobs/p/AD2zGS6BNa4R-Network-Security-Senior-Specialist-ACT-Advanced-Computer-Technology-Cairo-Egypt
# 14
# https://wuzzuf.net/jobs/p/51dYosi4XPmN-IT-Technical-Support-Specialist-Cairo-Egypt
# 15
# https://wuzzuf.net/jobs/p/e7RiE6WVzeOH-Backend-Developer-intella-Giza-Egypt
# 1
# https://wuzzuf.net/jobs/p/i7ukva87Ge3B-Technical-SME-Engineer-Algoriza-Giza-Egypt
# 2
# https://wuzzuf.net/jobs/p/2n5VpV8hHifa-Sr-Mobile-Developer-eSense-Amman-Jordan
# 3
# https://wuzzuf.net/jobs/p/ZI436tnODOTZ-Net-Technical-Lead-Asset-Technology-Group-Cairo-Egypt
# 4
# https://wuzzuf.net/jobs/p/mDQtLB87b0HS-Sr-Java-Developer-Asset-Technology-Group-Cairo-Egypt
# 5
# https://wuzzuf.net/jobs/p/dPX4Vw62oXVT-Senior-System-and-Network-Administrator-Kgroup-Cairo-Egypt
# 6
# https://wuzzuf.net/jobs/p/ZYcLdBqac9nv-IT-Help-Desk-Kgroup-Cairo-Egypt
# 7
# https://wuzzuf.net/jobs/p/fOe6zA8OZfUm-Senior-Backend-Developer---Part-Time-Zewail-City-Giza-Egypt
# 8
# https://wuzzuf.net/jobs/p/pDc5SokhW6S8-Azure-Cloud-Administrator-Charterhouse-Middle-East-Dubai-United-Arab-Emirates
# 9
# https://wuzzuf.net/jobs/p/qgLC4jOqQ7Rn-ENQUIRY-FOR-OBSTACLES-PRODUCTS-Sio365-Dubai-United-Arab-Emirates
# 10
# https://wuzzuf.net/jobs/p/2l3psdYBJqPa-RFQ---BEST-RATE-FOR-SUPPLY-OF-DOOR-KICK-PLATE-Sio365-Dubai-United-Arab-Emirates
# 11
# https://wuzzuf.net/jobs/p/T7WXXvQrO32V-Odoo-Developer-Technotown-Cairo-Egypt
# 12
# https://wuzzuf.net/jobs/p/YykA51iea6Jr-business-management-and-individuals-and-societies-dubai-Teachanywhere-Dubai-United-Arab-Emirates
# 13
# https://wuzzuf.net/jobs/p/uNl7yjiIfmuO-IT-Operations-Manager-Kgroup-Cairo-Egypt
# 14
# https://wuzzuf.net/jobs/p/HMEJtWYmVctE-Senior-PHP-Developer-Laravel-Safa-Soft-Cairo-Egypt
# 15
# https://wuzzuf.net/jobs/p/FeluBSsQtYBB-Quality-Control-Inspector-Breadfast-Cairo-Egypt
# 1
# https://wuzzuf.net/jobs/p/rQe7ak70Pwmd-Senior-Database-Administrator-Smart-Cards-application-Giza-Egypt
# 2
# https://wuzzuf.net/jobs/p/20JBtA81CuTm-Technical-Support-Specialist-Cairo-Cepack-Cairo-Egypt
# 3
# https://wuzzuf.net/jobs/p/ZhRwIPTqbLDN-Technical-Support-Specialist-Cepack-Alexandria-Egypt
# 4
# https://wuzzuf.net/jobs/p/yc4PS4E7LWep-Senior-Front-End-Developer-Informatique-Education-Cairo-Egypt
# 5
# https://wuzzuf.net/jobs/p/IkdtvnhIwbfq-Senior-Back-End-Developer-Node-Js-3D-Diagnostix-Cairo-Egypt
# 6
# https://wuzzuf.net/jobs/p/6qAf7XssuKLO-Scrum-Master--saudi-national-Royal-Cyber-Riyadh-Saudi-Arabia
# 7
# https://wuzzuf.net/jobs/p/jeMjxF5k87bd-IT-Help-Desk-Suez-Egypt
# 8
# https://wuzzuf.net/jobs/p/9dR9ZDhZllhU-Junior-Application-tester-and-quality-control-conveyou-Cairo-Egypt
# 9
# https://wuzzuf.net/jobs/p/PRgU8M4k0DUp-Senior-Front-End-Developer-Angular-etmana-Cairo-Egypt
# 10
# https://wuzzuf.net/jobs/p/hXnhTzwVifAI-Cloud-Architect-VAS-Integrated-Solutions-Cairo-Egypt
# 11
# https://wuzzuf.net/jobs/p/airL3yWAFl9j-Technician---Mechanical-MenaBev-Jobs-Jeddah-Saudi-Arabia
# 12
# https://wuzzuf.net/jobs/p/2g0UOcsarfJ7-Electrical-Technician---Ar-Ras-NOMAC-Riyadh-Saudi-Arabia
# 13
# https://wuzzuf.net/jobs/p/HoH00I8z3R9g-Senior-Engineer-Customer-Services-Raya-Holding-for-Financial-Investments-Cairo-Egypt
# 14
# https://wuzzuf.net/jobs/p/XJjTF7qQjrnK-3d-visualiser-Alert-International-Dubai-United-Arab-Emirates
# 15
# https://wuzzuf.net/jobs/p/5kSHdyu6P6uC-Technical-Support-Engineer-Olivery-Cairo-Egypt
# 1
# https://wuzzuf.net/jobs/p/zqnllixq8Gze-Second-Line-Support-and-Network-Data-Engineer-Cairo-Egypt
# 2
# https://wuzzuf.net/jobs/p/kd0zws5Vz8v7-Second-Line-Support-and-Systems-Security-Engineer-Cairo-Egypt
# 3
# https://wuzzuf.net/jobs/p/cJvbmNMcFEm9-ELV-Project-Sales-Engineer-International-Advanced-Riyadh-Saudi-Arabia
# 4
# https://wuzzuf.net/jobs/p/PGyYfufI3IBR-Business-Analyst-3S-Software-Cairo-Egypt
# 5
# https://wuzzuf.net/jobs/p/UGb0htOgXFmF-Help-Desk-Engineer-Cairo-Egypt
# 6
# https://wuzzuf.net/jobs/p/2lhLqVw2vxod-Information-Network-security-Engineer-Alexandria-Business-Association--SMEs-Project-Alexandria-Egypt
# 7
# https://wuzzuf.net/jobs/p/cFtxwHN02h34-IT-Senior-system-admin--nearby-to-10th-of-Ramadan-El-Banna-Group-Company-Sharqia-Egypt
# 8
# https://wuzzuf.net/jobs/p/etc9yxUMl40q-PMC-Senior-Process-Engineer---Propane-Dehydrogenation-Wood-Dubai-United-Arab-Emirates
# 9
# https://wuzzuf.net/jobs/p/eT5lGkmEJqUz-Process-Engineer---Automation-Wood-Dubai-United-Arab-Emirates
# 10
# https://wuzzuf.net/jobs/p/cRNlhJ6g0V7A-Senior-Estimator-–-Contracts-and-Services-Wood-Dubai-United-Arab-Emirates
# 11
# https://wuzzuf.net/jobs/p/6HKirAnN7tZL-Senior-Administration-Analyst-Raytheon-Riyadh-Saudi-Arabia
# 12
# https://wuzzuf.net/jobs/p/lyvcQgYy29kQ-Technical-Manager-UrbaCon-Contracting-Trading-Company-Doha-Qatar
# 13
# https://wuzzuf.net/jobs/p/Z77PkxY7eP1F-Assistant-Server---Room-Service-Four-Seasons-Hotels-and-Resorts-Dubai-United-Arab-Emirates
# 14
# https://wuzzuf.net/jobs/p/DUMYvoYwOzod-PHP-Developer-Dakahlia-Egypt
# 15
# https://wuzzuf.net/jobs/p/g43UpYEZuFSs-Senior-PHP-Laravel-Developer---Saudi-Arabaia---Remotely-Alexandria-For-Programming-Riyadh-Saudi-Arabia
# 1
# https://wuzzuf.net/jobs/p/MvOgeOj34k2v-Scrum-Master-Dimofinf-Operations-Center-Cairo-Egypt
# 2
# https://wuzzuf.net/jobs/p/BezOstM5qFck-Software-Quality-Control-Engineer-Alexandria-Egypt
# 3
# https://wuzzuf.net/jobs/p/2qiEChpCjNgn-Business-Analyst-Intern-McKinsey-Company-Abu-Dhabi-United-Arab-Emirates
# 4
# https://wuzzuf.net/jobs/p/sU6uQDBSENbU-Back-end-Support-MTS-IT-Cairo-Egypt
# 5
# https://wuzzuf.net/jobs/p/zFpJSordJd8q-VBCNET-3540-framework-ASPNET-Developer-Career-Raiser-Dubai-United-Arab-Emirates
# 6
# https://wuzzuf.net/jobs/p/uhQ6xTdpkCq3-Maintenance-Technician-CommuniCare-Health-Alexandria-Egypt
# 7
# https://wuzzuf.net/jobs/p/NeSe0ntbipWq-Required---Chemistry-teacher-EducoHire-Abu-Dhabi-United-Arab-Emirates
# 8
# https://wuzzuf.net/jobs/p/R5uTrjMNDpLr-BOLLARD-Sio365-Dubai-United-Arab-Emirates
# 9
# https://wuzzuf.net/jobs/p/osLrICOtpPEL-Required---Head-of-elementary-EducoHire-Abu-Dhabi-United-Arab-Emirates
# 10
# https://wuzzuf.net/jobs/p/BsmY9GLjAinx-QA-Engineer-Fintech-Optasia-Cairo-Egypt
# 11
# https://wuzzuf.net/jobs/p/4a5EZNG6NW7g-Senior-Devops-Engineer-Octane-solutions-Cairo-Egypt
# 12
# https://wuzzuf.net/jobs/p/16IJLP0cF4oN-Software-Engineer---Backend-Fintech-Optasia-Cairo-Egypt
# 13
# https://wuzzuf.net/jobs/p/gpa1y25Ebb7e-Senior-Jasper-DeveloperAdmin-FlairsTech-Cairo-Egypt
# 14
# https://wuzzuf.net/jobs/p/28UyaXymJXRB-Senior-UIUX-Designer-Remote-Saudi-Arabia-·-Posted-19-April-2022-Taffi-Inc-Riyadh-Saudi-Arabia
# 15
# https://wuzzuf.net/jobs/p/7rAvQ9issW7j-Required---English-Teachers-High-School-EducoHire-Abu-Dhabi-United-Arab-Emirates
# 1
# https://wuzzuf.net/jobs/p/b2BdlLm0r7pi-Required---Physics-teacher-EducoHire-Abu-Dhabi-United-Arab-Emirates
# 2
# https://wuzzuf.net/jobs/p/PEJGmBSfB2Gu-Required---Math-high-school-Teacher-EducoHire-Abu-Dhabi-United-Arab-Emirates
# 3
# https://wuzzuf.net/jobs/p/p0EdEKocdsEJ-Senior-Buying-Manager---Accessories-Career-Raiser-Dubai-United-Arab-Emirates
# 4
# https://wuzzuf.net/jobs/p/rHGUSLL50RFy-IT-Operation-Team-Lead-Caduceus-Lane-Alexandria-Egypt
# 5
# https://wuzzuf.net/jobs/p/2NDKOkggglmO-Quality-Assurance-Testing-Engineer-Giza-Egypt
# 6
# https://wuzzuf.net/jobs/p/CbjMdwLzGndR-System-Administrator-Arabia-for-Information-Technology-Cairo-Egypt
# 7
# https://wuzzuf.net/jobs/p/1dpQ9qb4MjEI-IT-Specialist-Cairo-Egypt
# 8
# https://wuzzuf.net/jobs/p/iRNx8l9PSd3s-SAP-system-admin-SAP-Business-One-Asass-Cairo-Egypt
# 9
# https://wuzzuf.net/jobs/p/9fl275lSzoe5-IT-Help-Desk-Amer-Vision-Group-Cairo-Egypt
# 10
# https://wuzzuf.net/jobs/p/gVyC6aCanNKX-Technical-Writer-Millensys-Cairo-Egypt
# 11
# https://wuzzuf.net/jobs/p/TmGWpQjQg3t1-Research-Specialist-Level-3-Weill-Cornell-Medicine-Qatar-Doha-Qatar
# 12
# https://wuzzuf.net/jobs/p/A43LQ0ZzBNKA-Senior-Full-Stack-Developer-Angular-Java-Cairo-Egypt
# 13
# https://wuzzuf.net/jobs/p/8hBr5NZdcLYN-Nursing-Excellence-Facilitator-Ministry-of-Defense--Medical-Services-Directorate-Riyadh-Saudi-Arabia
# 14
# https://wuzzuf.net/jobs/p/oDZ1WwMgowti-System-Administrator-Servmix-Cairo-Egypt
# 15
# https://wuzzuf.net/jobs/p/BSjUirh2MEj8-ERP-Implementer---Odoo-classera-Cairo-Egypt
# 1
# https://wuzzuf.net/jobs/p/fscvS4YgXXbN-Full-Stack-Developer-Net-Angular-GoodsMart-Cairo-Egypt
# 2
# https://wuzzuf.net/jobs/p/wSSqQrgucTFE-Senior-QA-Engineer-Agolo-Egypt-Cairo-Egypt
# 3
# https://wuzzuf.net/jobs/p/ZoV20iaw1VYS-Power-BI-Developer-eVision-Cairo-Egypt
# 4
# https://wuzzuf.net/jobs/p/4xH8PAl2A3NY-Android-Developer-Dakahlia-Egypt
# 5
# https://wuzzuf.net/jobs/p/1yOX2XVF6sti-Laravel-and-Vuejs-Developer-with-API-Integration-Experience-SellEnvo-Rotterdam-Netherlands
# 6
# https://wuzzuf.net/jobs/p/tnrWWMmY2xpO-Backend-PHP-Obeikan-Digital-Solutions-Cairo-Egypt
# 7
# https://wuzzuf.net/jobs/p/KkOfjy84iHck-Quality-Control-Engineer-Obeikan-Digital-Solutions-Cairo-Egypt
# 8
# https://wuzzuf.net/jobs/p/WYo4BJ7MbGJj-Frontend-Angular-Obeikan-Digital-Solutions-Cairo-Egypt
# 9
# https://wuzzuf.net/jobs/p/u45botSxRS0M-Node-JS-Developer-Obeikan-Digital-Solutions-Cairo-Egypt
# 10
# https://wuzzuf.net/jobs/p/mPcGDBla3Xmn-NET-WEB-DEVELOPER-Web-Forms-Informatique-Education-Cairo-Egypt
# 11
# https://wuzzuf.net/jobs/p/mtcMRAqm7jl5-Laravel-Developer-Kyan-Labs-Cairo-Egypt
# 12
# https://wuzzuf.net/jobs/p/4PEL7l05XKtA-Senior-Testing-Engineer-Al-Ahly-Momkn-for-e-payment-Cairo-Egypt
# 13
# https://wuzzuf.net/jobs/p/VDRM7gS9dALf-IT-Help-Desk-Cairo-Egypt
# 14
# https://wuzzuf.net/jobs/p/A0NnqG337cWi-Partnership-Manager-Cairo-Egypt
# 15
# https://wuzzuf.net/jobs/p/yrgDQrf44FOL-Electronics-Design-and-Development-Engineer-Allsopp-Allsopp-Recruitment-Dubai-United-Arab-Emirates
# 1
# https://wuzzuf.net/jobs/p/4yt0dasXdXbu-Outdoor-Environmental-Comfort-SME-Jacobs-Engineering-Group-Inc-Riyadh-Saudi-Arabia
# 2
# https://wuzzuf.net/jobs/p/5vln8ReOIbNJ-Sr-Custody-Exchange-Operations-Manager-BitOasis-Dubai-United-Arab-Emirates
# 3
# https://wuzzuf.net/jobs/p/QhQvRWCrxrcx-Lead-Engineer-Bureau-Veritas-Group-Riyadh-Saudi-Arabia
# 4
# https://wuzzuf.net/jobs/p/GAwdEW4PNzxC-Project-Manager-Radar-saab-group-Dubai-United-Arab-Emirates
# 5
# https://wuzzuf.net/jobs/p/Z1jJWuWaICsv-Project-Manager---Roads-Infrastructure-AECOM-Al-Ain-United-Arab-Emirates
# 6
# https://wuzzuf.net/jobs/p/EznTbWFW5CEC-Systems-Engineer---Abu-Dhabi-Fortinet-Inc-Abu-Dhabi-United-Arab-Emirates
# 7
# https://wuzzuf.net/jobs/p/avm5LeoDsEKt-Cyber-Security-Engineer-Giza-Egypt
# 8
# https://wuzzuf.net/jobs/p/YRr6jWpxGYuu-Senior-Director-CSS-Global-SaaS-and-Applications-Delivery-Jordan-Dreams-Dubai-United-Arab-Emirates
# 9
# https://wuzzuf.net/jobs/p/3pfpFlbMQbAI-Senior-Director-CSS-Global-SaaS-and-Applications-Delivery-Oracle---Egypt-Riyadh-Saudi-Arabia
# 10
# https://wuzzuf.net/jobs/p/axFJBpgi5JQv-high-school-maths-teachers---abu-dhabi-jan-2024-Teachanywhere-Dubai-United-Arab-Emirates
# 11
# https://wuzzuf.net/jobs/p/TVaWH00IFv0M-Field-Service-Rep-I---Drilling-Fluids-Halliburton-Energy-Services-Inc-Cairo-Egypt
# 12
# https://wuzzuf.net/jobs/p/TdCxHZZAy3TR-Teacher-Assistant-Suraasa-Dubai-United-Arab-Emirates
# 13
# https://wuzzuf.net/jobs/p/gTITPzhtkV8d-Logistics-Manager-Middle-East-Africa-Asia-Pacific-UtdArab-Emir-Dubai-Doka-USA-LTD-Dubai-United-Arab-Emirates
# 14
# https://wuzzuf.net/jobs/p/I881TsXQpwzs-HR-Project-Associate-Contract-Nathan-Nathan-Dubai-United-Arab-Emirates
# 15
# https://wuzzuf.net/jobs/p/gyziODjjuCWn-Business-Analyst-Intern-FWS-Group-Dubai-United-Arab-Emirates
# 1
# https://wuzzuf.net/jobs/p/A3khcMSejo1B-Would-you-like-to-teach-in-and-around-Dubai-SABIS®-Network-Schools-UAE-Oman-Qatar-and-Bahrain-Dubai-United-Arab-Emirates
# 2
# https://wuzzuf.net/jobs/p/tJLRN3zvgdmA-IT-Project-Management-Intern-NotionAce-Consulting-FZE-Dubai-United-Arab-Emirates
# 3
# https://wuzzuf.net/jobs/p/spP5G23XE72a-Sales-Manager-ERP-Bank-Alexandria-Egypt
# 4
# https://wuzzuf.net/jobs/p/0DfZBFunEzMi-IT-Service-Delivery-Specialist-UAE-National-Charterhouse-Middle-East-Dubai-United-Arab-Emirates
# 5
# https://wuzzuf.net/jobs/p/BjZKVNAeSamu-eCommerce---Solutions-Architect-Persistence-Recruitment-Riyadh-Saudi-Arabia
# 6
# https://wuzzuf.net/jobs/p/nsNFVGiOE6CC-IT-Support-Agent---Jumia-Full-Time-Jumia-Technologies-AG-Cairo-Egypt
# 7
# https://wuzzuf.net/jobs/p/Tb04GQhTOzvb-Senior-Engineer---Agile-DevSecOps-flydubai-Dubai-United-Arab-Emirates
# 8
# https://wuzzuf.net/jobs/p/XybrJdxt0y9P-Junior-Web-Developer-Back-End---Alexandria-Arabic-Localizer-Alexandria-Egypt
# 9
# https://wuzzuf.net/jobs/p/EQhtIeqBTDAq-SAP-FICO---TRM---COPA---FUND-Consultant-Galaxy-Consulting-Solutions-G-C-S-Cairo-Egypt
# 10
# https://wuzzuf.net/jobs/p/ijltnYGpgXOm-Oracle-HCM-Consultant-softprograms-Cairo-Egypt
# 11
# https://wuzzuf.net/jobs/p/DRkBYYAPpoXy-Solutions-Account-Manager---SASE-North-Gulf-Fortinet-Inc-Doha-Qatar
# 12
# https://wuzzuf.net/jobs/p/xxNdNrKCtjbW-Senior-FPA-Manager-BitOasis-Dubai-United-Arab-Emirates
# 13
# https://wuzzuf.net/jobs/p/f1A11Sg7fx5m-Construction-Apps---Solution-Designer-Persistence-Recruitment-Riyadh-Saudi-Arabia
# 14
# https://wuzzuf.net/jobs/p/Pv7qoZHbwWSx-Construction-Apps---Solutions-Architect-Persistence-Recruitment-Riyadh-Saudi-Arabia
# 15
# https://wuzzuf.net/jobs/p/wAVDqVRvK7yL-CRM---Solutions-Architect-Persistence-Recruitment-Riyadh-Saudi-Arabia
# 1
# https://wuzzuf.net/jobs/p/yTrGt7I2URgH-Senior-Analyst---Accounting-S-C-Johnson-Son-Inc-Cairo-Egypt
# 2
# https://wuzzuf.net/jobs/p/vYlJ6Kif6c1F-Solutions-Account-Manager---Cloud-North-Gulf-Fortinet-Inc-Doha-Qatar
# 3
# https://wuzzuf.net/jobs/p/VeSQgkmtzw4k-Outdoor-Environmental-Comfort-SME-Jacobs-Technology-Inc-Riyadh-Saudi-Arabia
# 4
# https://wuzzuf.net/jobs/p/bBpXEXoijlBJ-Collection-Executive---candidzone-Qureos-Doha-Qatar
# 5
# https://wuzzuf.net/jobs/p/eFYMjIaHK7Ku-Senior-Financial-Analyst-Merck-Sharp-Dohme-Corp-Cairo-Egypt
# 6
# https://wuzzuf.net/jobs/p/dgg7GQW490k7-SONOGRAPHER-NMC-Healthcare-Abu-Dhabi-United-Arab-Emirates
# 7
# https://wuzzuf.net/jobs/p/ZZnLnB6uKAOc-Software-Engineer-Aspnet-Loyapro-Riyadh-Saudi-Arabia
# 8
# https://wuzzuf.net/jobs/p/T1u18Zk4MenR-Assistant-I---Quality-Petrofac-Dubai-United-Arab-Emirates
# 9
# https://wuzzuf.net/jobs/p/fAbcdLQtTcaf-Head-of-Presales---EG---EBS-Giza-Arabia-Systems-Cairo-Egypt
# 10
# https://wuzzuf.net/jobs/p/ZgXOY7CppTkT-Technical-Trainer-FlairsTech-Cairo-Egypt
# 11
# https://wuzzuf.net/jobs/p/SPMFuLlhBRQO-eCommerce---Solution-Designer-Persistence-Recruitment-Riyadh-Saudi-Arabia
# 12
# https://wuzzuf.net/jobs/p/n2thGi8Xyqlc-CRM---Solutions-Designer-Persistence-Recruitment-Riyadh-Saudi-Arabia
# 13
# https://wuzzuf.net/jobs/p/0yKIaSPoIEul-Cyber-Security-Engineer-Almoosa-Specialist-Hospital-Riyadh-Saudi-Arabia
# 14
# https://wuzzuf.net/jobs/p/R4n8C01X1MeP-Warehouse-Assistant-Al-Futtaim-Automotive-Supply-Chain-Global-Aftersales-Al-Futtaim-Group---Other-locations-Dubai-United-Arab-Emirates
# 15
# https://wuzzuf.net/jobs/p/RJyavGXNtINx-Football-Systems-Operator---UAE-Hawk-Eye-Innovations-Ltd-Dubai-United-Arab-Emirates
# 1
# https://wuzzuf.net/jobs/p/B07tM4EOuNeU-Construction-Apps---Solutions-Delivery-Manager-Persistence-Recruitment-Riyadh-Saudi-Arabia
# 2
# https://wuzzuf.net/jobs/p/g2gDBX1nddvz-BIM-Solutions-Designer-Persistence-Recruitment-Riyadh-Saudi-Arabia
# 3
# https://wuzzuf.net/jobs/p/Kt2v6XkhS86H-Senior-Manager-–-Trade-Product-Management-ADCB-Abu-Dhabi-Commercial-Bank-Dubai-United-Arab-Emirates
# 4
# https://wuzzuf.net/jobs/p/eyAdOdJxBGvK-Bell-Attendant-Beach-Rotana-Abu-Dhabi-United-Arab-Emirates
# 5
# https://wuzzuf.net/jobs/p/G8KefbpJxcIv-Warehouse-Supervisor-Al-Futtaim-Automotive-Supply-Chain-Global-Aftersales-Al-Futtaim-Group---Other-locations-Dubai-United-Arab-Emirates
# 6
# https://wuzzuf.net/jobs/p/rwLsCDtfoRoy-IT-Business-Analyst---Saudi-National-Preferred-Persistence-Recruitment-Riyadh-Saudi-Arabia
# 7
# https://wuzzuf.net/jobs/p/hizmh8SjOxUr-Application-Developer-Java-Web-Technologies-IBM-WTC-Egypt-Cairo-Egypt
# 8
# https://wuzzuf.net/jobs/p/X0kgkqYD2epW-Front-Desk-Agent-Villa-Rotana-Dubai-United-Arab-Emirates
# 9
# https://wuzzuf.net/jobs/p/BiQEgy85fGnE-Senior-Data-Analytics-Specialist-Etihad-Airways-Abu-Dhabi-United-Arab-Emirates
# 10
# https://wuzzuf.net/jobs/p/G5iXAxCnPntQ-Technical-Engineer-UHRS-Dubai-United-Arab-Emirates
# 11
# https://wuzzuf.net/jobs/p/nqfdIy87lmfc-CRM---Solutions-Delivery-Manager-Persistence-Recruitment-Riyadh-Saudi-Arabia
# 12
# https://wuzzuf.net/jobs/p/n7rr3FEuWy2j-BIM-Solutions-Architect-Persistence-Recruitment-Riyadh-Saudi-Arabia
# 13
# https://wuzzuf.net/jobs/p/E75C36qOZcHO-IT-Support-Assitant-Abu-Dhabi-School-of-Management-Dubai-United-Arab-Emirates
# 14
# https://wuzzuf.net/jobs/p/ODfFFz1qxSPu-Project-Manager---SKID-ManpowerGroup-Middle-East-Dubai-United-Arab-Emirates
# 15
# https://wuzzuf.net/jobs/p/3hLprvq5MrMR-Business-Analyst-ManpowerGroup-Middle-East-Dubai-United-Arab-Emirates
# 1
# https://wuzzuf.net/jobs/p/7HkPKNBJ1wJE-Head-of-Technical-Delivery--Government-Business-Solutions-Giza-Arabia-Systems-Cairo-Egypt
# 2
# https://wuzzuf.net/jobs/p/bOHyMGWsJGou-IT-Manager-Allsopp-Allsopp-Recruitment-Dubai-United-Arab-Emirates
# 3
# https://wuzzuf.net/jobs/p/acXov9S4S38d-eCommerce---Solutions-Delivery-Manager-Persistence-Recruitment-Riyadh-Saudi-Arabia
# 4
# https://wuzzuf.net/jobs/p/o0S42RyTgpNa-Principal-Solution-Architect---EdgeOne-Tencent-Dubai-United-Arab-Emirates
# 5
# https://wuzzuf.net/jobs/p/eFE6NeBUdA7E-Graduate-Process-Engineer-UAE-National-Wood-Dubai-United-Arab-Emirates
# 6
# https://wuzzuf.net/jobs/p/v5PmPmlFV6lQ-Computer-System-Support-Specialist-3597-Three-Saints-Bay-LLC-Kuwait-City-Kuwait
# 7
# https://wuzzuf.net/jobs/p/oCIoHfljtyLR-TECHNICIAN---REEFER-Cargoes-Dubai-United-Arab-Emirates
# 8
# https://wuzzuf.net/jobs/p/VdRTBA67MdzE-Solutions-Architect-Intern-AWS-EMEA-SARL-Saudi-Arabia-Branch-Riyadh-Saudi-Arabia
# 9
# https://wuzzuf.net/jobs/p/WfDXZOEqZ9O7-Senior-Python-Developer-FlairsTech-Cairo-Egypt
# 10
# https://wuzzuf.net/jobs/p/nyITYuDyAcet-English-Customer-Support---PREMIUM-Sutherland-Cairo-Egypt
# 11
# https://wuzzuf.net/jobs/p/Ij4pLZy8zXP1-Next-JS-developer-Sceel-io-Cairo-Egypt
# 12
# https://wuzzuf.net/jobs/p/oLf9fme2Hy0p-Engineer-I---Quality-Petrofac-Dubai-United-Arab-Emirates
# 13
# https://wuzzuf.net/jobs/p/8RmO0pRLG2Hy-TECHNICIAN---REEFER-DP-World-Dubai-United-Arab-Emirates
# 14
# https://wuzzuf.net/jobs/p/MMczSX76dEuO-Senior-Officer-–-Commercial-Systems-flydubai-Dubai-United-Arab-Emirates
# 15
# https://wuzzuf.net/jobs/p/4ewsaSshlnvt-DLP-Engineer-Symantec-Help-AG-Riyadh-Saudi-Arabia
# 1
# https://wuzzuf.net/jobs/p/rE9mH4YWNWeC-Senior-Network-Security-Engineer-Help-AG-Riyadh-Saudi-Arabia
# 2
# https://wuzzuf.net/jobs/p/tPBMYnuRbEto-Strategic-Security---GRC-Consultant-Help-AG-Dubai-United-Arab-Emirates
# 3
# https://wuzzuf.net/jobs/p/zi5BbuFZBZoI-VP-of-Engineering-Foreground-Consultancy-Riyadh-Saudi-Arabia
# 4
# https://wuzzuf.net/jobs/p/SxQKE5MMfBhm-En-Ar-Reviewer-BayanTech-Cairo-Egypt
# 5
# https://wuzzuf.net/jobs/p/N8RcW1ySJhH4-IT-Audit-Supervisor-Foreground-Consultancy-Doha-Qatar
# 6
# https://wuzzuf.net/jobs/p/YYRiZ7IN29sw-Senior-PR-Account-Manager-Foreground-Consultancy-Riyadh-Saudi-Arabia
# 7
# https://wuzzuf.net/jobs/p/LUUghmtnRJnE-MLRO-Compliance-Manager-Foreground-Consultancy-Riyadh-Saudi-Arabia
# 8
# https://wuzzuf.net/jobs/p/aN6itfklY4Dh-Senior-HSEQ-Trainer-BD-SELECT-Doha-Qatar
# 9
# https://wuzzuf.net/jobs/p/JcRUzE4YOGZU-Localization-Project-Manager-BayanTech-Cairo-Egypt
# 10
# https://wuzzuf.net/jobs/p/Bp4eOq4AU0eB-Offshore-Team-Leader-Call-Center---Dispatching-BayanTech-Cairo-Egypt
# 11
# https://wuzzuf.net/jobs/p/umrJrmCWZlqS-Quality-Assurance-Executive-data-analysis--internal-auditing-BayanTech-Cairo-Egypt
# 12
# https://wuzzuf.net/jobs/p/Z2TYDflS4dQa-Data-Governance-Manager-Foreground-Consultancy-Doha-Qatar
# 13
# https://wuzzuf.net/jobs/p/xEmGuFGsA2iF-Assistant-Consultant---Neurosurgery-Eastern-Health-Cluster-Dammam-Saudi-Arabia
# 14
# https://wuzzuf.net/jobs/p/osyalY7CoiKe-Senior-Account-Director-Foreground-Consultancy-Riyadh-Saudi-Arabia
# 15
# https://wuzzuf.net/jobs/p/dRZLAdO6I7be-Senior-Sales-Consultant-Foreground-Consultancy-Riyadh-Saudi-Arabia
# 1
# https://wuzzuf.net/jobs/p/Qw4yQv27ZyXN-UI-UX-Top-Notch-Consultancy-Jeddah-Saudi-Arabia
# 2
# https://wuzzuf.net/jobs/p/PKlS4GDdwbnv-Onshore-Engineering-Lead-BD-SELECT-Doha-Qatar
# 3
# https://wuzzuf.net/jobs/p/aaOq1w25TGvu-Data-Warehousing---Oil-Gas-BD-SELECT-Doha-Qatar
# 4
# https://wuzzuf.net/jobs/p/yFolwuqf8DIw-Project-Administrator-Transguard-group-Dubai-United-Arab-Emirates
# 5
# https://wuzzuf.net/jobs/p/hsdJDC74Yi7g-Pre-sales-Solution-Architect-Top-Notch-Consultancy-Doha-Qatar
# 6
# https://wuzzuf.net/jobs/p/Bzj8fMmfbcQM-CRM-Business-Analyst-Top-Notch-Consultancy-Riyadh-Saudi-Arabia
# 7
# https://wuzzuf.net/jobs/p/iJ3cTwNyUANf-VP-Asset-Allocator-Foreground-Consultancy-Kuwait-City-Kuwait
# 8
# https://wuzzuf.net/jobs/p/TMQCY8tOGoKe-Head-of-Research-Development-Foreground-Consultancy-Kuwait-City-Kuwait
# 9
# https://wuzzuf.net/jobs/p/16Vhcj7YCLpj-QAQC-Engineer-People-One-Doha-Qatar
# 10
# https://wuzzuf.net/jobs/p/utUezZSxIDPu-Project-Manager-Hybrid-BayanTech-Cairo-Egypt
# 11
# https://wuzzuf.net/jobs/p/W088eil25CX6-Assistant-Project-Manager-BD-SELECT-Doha-Qatar
# 12
# https://wuzzuf.net/jobs/p/NBM2RDKDsZce-Assistant-FB-Manager-Foreground-Consultancy-Riyadh-Saudi-Arabia
# 13
# https://wuzzuf.net/jobs/p/KhrAR5QRq2HJ-Technical-Assessment-Analyst-Saudi-Petroleum-Services-Polytechnic-Dammam-Saudi-Arabia
# 14
# https://wuzzuf.net/jobs/p/LZxeCUTBMctZ-UIUX-Web-Designer-Nile-Creations-Cairo-Egypt
# 15
# https://wuzzuf.net/jobs/p/XKwYb9FyfIhC-iOS-Developer-34ML-Cairo-Egypt
# 1
# https://wuzzuf.net/jobs/p/FPig5HallEZj-VueJS-Frontend-Developer-34ML-Cairo-Egypt
# 2
# https://wuzzuf.net/jobs/p/SQ3SKXvIUcdp-Executive-Support-Specialist-Foreground-Consultancy-Doha-Qatar
# 3
# https://wuzzuf.net/jobs/p/liZhHfNMQJw8-Senior-Security-Consultant---Network-Help-AG-Riyadh-Saudi-Arabia
# 4
# https://wuzzuf.net/jobs/p/aNQNOuLkg5ka-Software-Quality-Control-Specialist-Arabia-for-Information-Technology-Cairo-Egypt
# 5
# https://wuzzuf.net/jobs/p/jSkuBjfcMjLB-Senior-Administrative-Assistant-Mekdam-Holding-Group-Doha-Qatar
# 6
# https://wuzzuf.net/jobs/p/ArkEFRymbVgn-Road-Pavement-Specialist-Mekdam-Holding-Group-Doha-Qatar
# 7
# https://wuzzuf.net/jobs/p/ARTx3reU7EcN-Technical-Writers-OES-Mekdam-Holding-Group-Doha-Qatar
# 8
# https://wuzzuf.net/jobs/p/Ghwir3AvoDJN-SENIOR-OPERATIONS-ENGINEER-OFFSHORE-Mekdam-Holding-Group-Doha-Qatar
# 9
# https://wuzzuf.net/jobs/p/psw3RDgSMFPq-MP-Quality-Governance-and-Management-System-Lead-T-1541-2-Mekdam-Holding-Group-Doha-Qatar
# 10
# https://wuzzuf.net/jobs/p/99McVGo10jCV-Control-System-Engineer-EP-Mekdam-Holding-Group-Doha-Qatar
# 11
# https://wuzzuf.net/jobs/p/55Bz4HWJAV6o-Senior-Application-Expert-Administration-Mekdam-Holding-Group-Doha-Qatar
# 12
# https://wuzzuf.net/jobs/p/ZoEBUxmYCZt6-Head-Project-Engineer-Utilities-Offsite-EPC-1-N-1606-Mekdam-Holding-Group-Doha-Qatar
# 13
# https://wuzzuf.net/jobs/p/PzDJ5dKyODsF-Telecommunications-Mekdam-Holding-Group-Doha-Qatar
# 14
# https://wuzzuf.net/jobs/p/p4fSwULJgEs4-Event-Project-Manager-Foreground-Consultancy-Riyadh-Saudi-Arabia
# 15
# https://wuzzuf.net/jobs/p/Gy3TJIbaAon6-Lead-of-ProcessUtilities-F-4212-Q-Mekdam-Holding-Group-Doha-Qatar
# 1
# https://wuzzuf.net/jobs/p/xPwWBuWucerq-Lead-of-Quality-BGD---Lean-Gas-Lines-N-1961-2-Mekdam-Holding-Group-Doha-Qatar
# 2
# https://wuzzuf.net/jobs/p/41KFntpFHMo7-Lead-of-Security-and-Emergency-Response-S-1521---3-Mekdam-Holding-Group-Doha-Qatar
# 3
# https://wuzzuf.net/jobs/p/8Am5509XXUv4-SR-PLANNING-AND-BUSINESS-SUPPORT-SPECIALIST-Mekdam-Holding-Group-Doha-Qatar
# 4
# https://wuzzuf.net/jobs/p/ymFLuCJwLY9Y-RFP-Specialist-Foreground-Consultancy-Riyadh-Saudi-Arabia
# 5
# https://wuzzuf.net/jobs/p/zRRbpY6UTv9U-Security-Consultant---Network-Help-AG-Riyadh-Saudi-Arabia
# 6
# https://wuzzuf.net/jobs/p/TcdNOjHFJYI4-Senior-SAP-Security-and-GRC-Consultant-Mekdam-Holding-Group-Doha-Qatar
# 7
# https://wuzzuf.net/jobs/p/0qSrhVZTRNRg-Applications-Development-Consultant-NET-Mekdam-Holding-Group-Doha-Qatar
# 8
# https://wuzzuf.net/jobs/p/E05GK0d5zvQB-Lead-of-Telecom-F-1307F-1306-F-1288---3-Mekdam-Holding-Group-Doha-Qatar
# 9
# https://wuzzuf.net/jobs/p/OZOU4oaYEUtQ-ICSS-Lead-Utilities-EPC-1-Mekdam-Holding-Group-Doha-Qatar
# 10
# https://wuzzuf.net/jobs/p/KnIIOmH66WzN-Lead-of-Internal-Project-Interfaces-Shared-Resources-F-1298-Q-3-Mekdam-Holding-Group-Doha-Qatar
# 11
# https://wuzzuf.net/jobs/p/jD0QF3fmxCqf-TPC-Operator-Mekdam-Holding-Group-Doha-Qatar
# 12
# https://wuzzuf.net/jobs/p/DwQvEFhQ6AxB-Lead-Project-Assessment-E-1235-Q-Mekdam-Holding-Group-Doha-Qatar
# 13
# https://wuzzuf.net/jobs/p/7DUCgYmwK8Yk-Senior-SAP-JVA-Techno-Functional-Consultant-Mekdam-Holding-Group-Doha-Qatar
# 14
# https://wuzzuf.net/jobs/p/Jg6HYwNmDdjE-Lead-of-Planning-COMP13-F-1210-Q-Mekdam-Holding-Group-Doha-Qatar
# 15
# https://wuzzuf.net/jobs/p/PDT4PtJcYDax-UAT-Tester-Mekdam-Holding-Group-Doha-Qatar
# 1
# https://wuzzuf.net/jobs/p/b35zlLzn6Two-Lead-of-Project-Engineering-COMP3-F-4322-Q-2-Mekdam-Holding-Group-Doha-Qatar
# 2
# https://wuzzuf.net/jobs/p/bYTqWJIiVhW5-Senior-Structural-Engineer-Mekdam-Holding-Group-Doha-Qatar
# 3
# https://wuzzuf.net/jobs/p/2zYNhliBzPFY-Lead-of-Electrical-Offplots-Shared-Resource-N-2731-1-Mekdam-Holding-Group-Doha-Qatar
# 4
# https://wuzzuf.net/jobs/p/gmhavwiY9jRT-Senior-Engineer-IT-Mekdam-Holding-Group-Doha-Qatar
# 5
# https://wuzzuf.net/jobs/p/0WS9OjAjNVfY-Senior-Application-Analyst-Mekdam-Holding-Group-Doha-Qatar
# 6
# https://wuzzuf.net/jobs/p/NOx3znZZ2BRp-DEVELOPMENT-ENGINEER-Mekdam-Holding-Group-Doha-Qatar
# 7
# https://wuzzuf.net/jobs/p/cTHCw5InBPOI-Senior-Legal-Manager-Foreground-Consultancy-Riyadh-Saudi-Arabia
# 8
# https://wuzzuf.net/jobs/p/lfWzCmuMAiXB-Network-Admin-Support-Lead-Foreground-Consultancy-Doha-Qatar
# 9
# https://wuzzuf.net/jobs/p/HLslH6i9MyL0-Lead-of-Interface-NFS-EPC-2-N-1617-Mekdam-Holding-Group-Doha-Qatar
# 10
# https://wuzzuf.net/jobs/p/27UdyA7OurQk-Head-Project-Controls-EPC-2-N-1965-Mekdam-Holding-Group-Doha-Qatar
# 11
# https://wuzzuf.net/jobs/p/qXxYAO9ENdnt-Specialist-EPM-Solutions-Oracle-Mekdam-Holding-Group-Doha-Qatar
# 12
# https://wuzzuf.net/jobs/p/mU0exvmjtnBr-Project-Controls-Specialist-EPC-4-N-2025---2-Mekdam-Holding-Group-Doha-Qatar
# 13
# https://wuzzuf.net/jobs/p/w5d7IgU51Ebp-Lead-of-Static-Equipment-Shared-Resources-F-1247-3-Q-Mekdam-Holding-Group-Doha-Qatar
# 14
# https://wuzzuf.net/jobs/p/QHPxTQlVK7KD-Product-Owner-QARA-Cairo-Egypt
# 15
# https://wuzzuf.net/jobs/p/msHyQcVIRmyw-ICSS-Lead-Utilities-EPC-1-N-1884---3-Mekdam-Holding-Group-Doha-Qatar
# 1
# https://wuzzuf.net/jobs/p/CTqazWHiXfZo-QAQC-Engineer-Mekdam-Holding-Group-Doha-Qatar
# 2
# https://wuzzuf.net/jobs/p/51gVZJuqDubx-SAP-Sr-FICO-Techno-Functional-Consultant-Mekdam-Holding-Group-Doha-Qatar
# 3
# https://wuzzuf.net/jobs/p/wz8ZS43mSWJg-Instrumentation-Lead-Utilities-EPC-1-N-1881-Mekdam-Holding-Group-Doha-Qatar
# 4
# https://wuzzuf.net/jobs/p/vOx2OWElRR0M-Lead-of-Execution-Offshore---E-1230-Q-Mekdam-Holding-Group-Doha-Qatar
# 5
# https://wuzzuf.net/jobs/p/xEIKCcF98iuG-Security-Lead-Mekdam-Holding-Group-Doha-Qatar
# 6
# https://wuzzuf.net/jobs/p/eUnTCZWEz2Xo-Lead-of-Planning-COMP13-Shared-Resources-Mekdam-Holding-Group-Doha-Qatar
# 7
# https://wuzzuf.net/jobs/p/LDFynhGhPvlJ-Traffic-Signals-Mekdam-Holding-Group-Doha-Qatar
# 8
# https://wuzzuf.net/jobs/p/jz2ZWB7b1MWZ-Lead-of-Site-Planning-EPC-34-N-1217-1-Mekdam-Holding-Group-Doha-Qatar
# 9
# https://wuzzuf.net/jobs/p/NWiI7v7JbOk3-Business-Systems-Integration-Manager-Mekdam-Holding-Group-Doha-Qatar
# 10
# https://wuzzuf.net/jobs/p/f4WLklQ4v3fX-Head-of-System-Completion-COMP1-F-4480-Q-Mekdam-Holding-Group-Doha-Qatar
# 11
# https://wuzzuf.net/jobs/p/avFVsXLS1wk4-Lead-of-Transportation-and-Installation-Execution-for-PipelinesCables-F-1283-Q-2-Mekdam-Holding-Group-Doha-Qatar
# 12
# https://wuzzuf.net/jobs/p/Su7iXKlHqdyk-Training-Instructors-OES-Mekdam-Holding-Group-Doha-Qatar
# 13
# https://wuzzuf.net/jobs/p/DspX3dUYfjik-Technical-Consultant-Top-Notch-Consultancy-Doha-Qatar
# 14
# https://wuzzuf.net/jobs/p/JGkMl5Fgjeu9-Hardware-Design-Engineer-idaco-Giza-Egypt
# 15
# https://wuzzuf.net/jobs/p/Il21UahywJhI-flutter-developer-idaco-Giza-Egypt
# 1
# https://wuzzuf.net/jobs/p/m0cgk1CAfmNO-Business-Analyst-WSC-Giza-Egypt
# 2
# https://wuzzuf.net/jobs/p/hSbhg9V3Lno8-Software-Project-Manager-Asset-Technology-Group-Cairo-Egypt
# 3
# https://wuzzuf.net/jobs/p/FgV9QUxDIiEq-Developer-Analyst-Cairo-Egypt
# 4
# https://wuzzuf.net/jobs/p/UQcvQCl6wJHg-Senior-Quality-Assurance-Testers-Al-Ahly-capital-holding---Al-Ahly-Tamkeen-Cairo-Egypt
# 5
# https://wuzzuf.net/jobs/p/ZTnaIa06qi4N-Application-Support-Manager-MaximoKronos-Farah-Experiences-LLC-Dubai-United-Arab-Emirates
# 6
# https://wuzzuf.net/jobs/p/EKoDfurHm6cx-Architect-Stantec-Dubai-United-Arab-Emirates
# 7
# https://wuzzuf.net/jobs/p/6UJbKSlwpESg-Business-Analyst---Saudi-National-Preferred-Persistence-Recruitment-Riyadh-Saudi-Arabia
# 8
# https://wuzzuf.net/jobs/p/TNMOxhhnGo7l-Software-Development-Engineer-Amazon-MENA-Dubai-United-Arab-Emirates
# 9
# https://wuzzuf.net/jobs/p/j3gtWTJtzrdS-Vendor-Consultant-Spanish-Amazon-MENA-Cairo-Egypt
# 10
# https://wuzzuf.net/jobs/p/gyu5yCoFr7FB-Drupal-Developer-WSC-Giza-Egypt
# 11
# https://wuzzuf.net/jobs/p/MWuZdH52gYo9-Operational-Excellence-Mechanical-Integrity-Engineer-Air-Products-Middle-East-FZE-Khobar-Saudi-Arabia
# 12
# https://wuzzuf.net/jobs/p/zqnJVMcfBfJ9-Lead-Systems-Engineer-Air-Products-Middle-East-FZE-Jizan-Saudi-Arabia
# 13
# https://wuzzuf.net/jobs/p/RwDUFBPl8koo-Senior-Splunk-Engineer-Help-AG-Riyadh-Saudi-Arabia
# 14
# https://wuzzuf.net/jobs/p/y580Lnvk6DDi-Identity-Security-Solution-Engineer-Help-AG-Dubai-United-Arab-Emirates
# 15
# https://wuzzuf.net/jobs/p/hXfgJMqkz5UG-GRC-Consultant-Help-AG-Riyadh-Saudi-Arabia
# 1
# https://wuzzuf.net/jobs/p/MOMPj4FnYlKx-Senior-Cybersecurity-Engineer---SOC-Help-AG-Riyadh-Saudi-Arabia
# 2
# https://wuzzuf.net/jobs/p/JHuL9nPKnbHs-Senior-Network-Security-Consultant-Help-AG-Dubai-United-Arab-Emirates
# 3
# https://wuzzuf.net/jobs/p/2v1og8r8GeDJ-Service-Renewals-Specialist-Help-AG-Dubai-United-Arab-Emirates
# 4
# https://wuzzuf.net/jobs/p/hFYDsUzwm1Vm-Programme-Associate-2-Months-Contract-UHRS-Dubai-United-Arab-Emirates
# 5
# https://wuzzuf.net/jobs/p/wa7Rvk38cq5E-Speaker-Manager-2-Months-Contract-UHRS-Dubai-United-Arab-Emirates
# 6
# https://wuzzuf.net/jobs/p/0FcbjHVxMG5m-System-Admin-BayanTech-Cairo-Egypt
# 7
# https://wuzzuf.net/jobs/p/4ApwOxH6pAUd-Hard-Services-Manager-Foreground-Consultancy-Doha-Qatar
# 8
# https://wuzzuf.net/jobs/p/peijGnaCV7j2-Backend-Developer-Net-WSC-Giza-Egypt
# 9
# https://wuzzuf.net/jobs/p/WC8rrGyhxlQE-Senior-Android-Developer-YOUXEl-Technology-Cairo-Egypt
# 10
# https://wuzzuf.net/jobs/p/AdHb0yBXwf1y-Technical-Support-Engineer---German-Speaker-TechJump-Alexandria-Egypt
# 11
# https://wuzzuf.net/jobs/p/dqyq4eBRSXLY-Quality-Assurance-Tester-Al-Ahly-capital-holding---Al-Ahly-Tamkeen-Cairo-Egypt
# 12
# https://wuzzuf.net/jobs/p/mglE8QL3wohZ-Senior-Odoo-Developer-ITSS-Cairo-Egypt
# 13
# https://wuzzuf.net/jobs/p/DlHst5Aen4XD-Technical-Recruiter-Dimofinf-Operations-Center-Cairo-Egypt
# 14
# https://wuzzuf.net/jobs/p/bVQoawtlI7Z2-Consultant-Robiquity-Cairo-Egypt
# 15
# https://wuzzuf.net/jobs/p/of1FnUdwgN2x-Associate-Consultant-Robiquity-Cairo-Egypt
# 1
# https://wuzzuf.net/jobs/p/mRkhbxDDA5LX-SR-JAVA-ADF-Developer-egabi-solutions-Cairo-Egypt
# 2
# https://wuzzuf.net/jobs/p/zBBYc4sbl1i3-Technician-IV-Hail-Mechanical-Job-Tasnee-Hail-Saudi-Arabia
# 3
# https://wuzzuf.net/jobs/p/mwLrPdz6NYkh-Football-Systems-Operator---Saudi-Arabia-Riyadh-Hawk-Eye-Innovations-Ltd-Riyadh-Saudi-Arabia
# 4
# https://wuzzuf.net/jobs/p/pKqC61rPaMZl-Core-Assurance-COOPs---All-KSA-PwC---United-Arab-Emirates-Riyadh-Saudi-Arabia
# 5
# https://wuzzuf.net/jobs/p/6kv00zyIOHgJ-Senior-Commercial-Manager-Jacobs-Engineering-Group-Inc-Riyadh-Saudi-Arabia
# 6
# https://wuzzuf.net/jobs/p/VSbRK7VF07jb-Senior-Commercial-Manager-Jacobs-Technology-Inc-Riyadh-Saudi-Arabia
# 7
# https://wuzzuf.net/jobs/p/8wwHHop2FPtU-Security-Engineer-OT-Tenable-Dubai-United-Arab-Emirates
# 8
# https://wuzzuf.net/jobs/p/bFgPiNZTSwPI-Senior-Engineer-–-Biomedical-Sidra-Medicine-Doha-Qatar
# 9
# https://wuzzuf.net/jobs/p/h2sq3POtK4MR-Associate-Technology-service-ITMAM-Abu-Dhabi-United-Arab-Emirates
# 10
# https://wuzzuf.net/jobs/p/Wgv9wviV80fr-Oracle-EBS-Financial-Consultant-softprograms-Cairo-Egypt
# 11
# https://wuzzuf.net/jobs/p/0GpRk8WYuNQv-QAQC-Engineer-GHD-Abu-Dhabi-United-Arab-Emirates
# 12
# https://wuzzuf.net/jobs/p/A0NCtmP3SLe3-E2E-Ops-Performance-Director-Splonline-Riyadh-Saudi-Arabia
# 13
# https://wuzzuf.net/jobs/p/OsLD3lR1UJrO-TECHNICIAN---AC-DP-World-Dubai-United-Arab-Emirates
# 14
# https://wuzzuf.net/jobs/p/LAkBzKZYTN6K-Oracle-ADF-Developer-Cairo-Egypt
# 15
# https://wuzzuf.net/jobs/p/ukEhQkrR0V5x-Front-End-Developer-Erpplus5-Cairo-Egypt
# 1
# https://wuzzuf.net/jobs/p/BHJqFbLf5N2c-Business-Analyst-Erpplus5-Cairo-Egypt
# 2
# https://wuzzuf.net/jobs/p/WeKRBy1p3Oxo-Software-Quality-Control-and-Tester-Erpplus5-Cairo-Egypt
# 3
# https://wuzzuf.net/jobs/p/TqqfXUbbZyDQ-Software-Tester-Cairo-Egypt
# 4
# https://wuzzuf.net/jobs/p/uzN3wDuRrR08-ENQUIRY-FOR-FROZEN-CHICKEN-Sio365-Dubai-United-Arab-Emirates
# 5
# https://wuzzuf.net/jobs/p/cs64RGLHjkQy-Senior-Python-Docker-Flask-developer-GetTechForce-com-Cairo-Egypt
# 6
# https://wuzzuf.net/jobs/p/E1IodkBW5Yt5-Senior-Full-Stack-Developer-GetTechForce-com-Cairo-Egypt
# 7
# https://wuzzuf.net/jobs/p/olEB8N8atm7f-Senior-Data-Engineer---Remote-GetTechForce-com-Cairo-Egypt
# 8
# https://wuzzuf.net/jobs/p/h6YRz1PpjFgD-Information-Security-Engineer-Easy-Cash-Cairo-Egypt
# 9
# https://wuzzuf.net/jobs/p/z9u9DrOQL6yW-PMC-Senior-IC-Engineer-John-Wood-Group-PLC-Dubai-United-Arab-Emirates
# 10
# https://wuzzuf.net/jobs/p/RIzPmjcHAnv7-SOC-Analyst-Level-2-Itsecurityct-Riyadh-Saudi-Arabia
# 11
# https://wuzzuf.net/jobs/p/Ni8nMlF3wO27-Data-Analyst-Specialist-Almoosa-Specialist-Hospital-Riyadh-Saudi-Arabia
# 12
# https://wuzzuf.net/jobs/p/ea2Pniy7ruMs-SMESolution-Architect---Oracle-HealthPlan-Services-Inc-Dubai-United-Arab-Emirates
# 13
# https://wuzzuf.net/jobs/p/lksmL0bSFJTk-Software-Engineer-flydubai-Dubai-United-Arab-Emirates
# 14
# https://wuzzuf.net/jobs/p/Z1bJ5RP7giKZ-Consulting-Finance-Accounting---Director-RiyadhDubai-PwC---United-Arab-Emirates-Riyadh-Saudi-Arabia
# 15
# https://wuzzuf.net/jobs/p/JGVunLHu57RP-Senior-Inventory-Analyst-Etihad-Airways-Abu-Dhabi-United-Arab-Emirates
# 1
# https://wuzzuf.net/jobs/p/Eusf9YSxipFQ-ENQUIRY-FOR-HDPE-GRANULES-Sio365-Dubai-United-Arab-Emirates
# 2
# https://wuzzuf.net/jobs/p/BfxS80kT2wen-Principal-Engineer---Cathodic-Protection-Petrofac-Dubai-United-Arab-Emirates
# 3
# https://wuzzuf.net/jobs/p/lr4dgFI8gtWo-Manager-Network-Revenue-Optimization-Etihad-Airways-Abu-Dhabi-United-Arab-Emirates
# 4
# https://wuzzuf.net/jobs/p/EyoTIKwPupY7-Test-SpecialistMiddleware-IBM-WTC-Egypt-Cairo-Egypt
# 5
# https://wuzzuf.net/jobs/p/T6Np4TtYp6PI-Technical-Lead-LINK-TSP-Cairo-Egypt
# 6
# https://wuzzuf.net/jobs/p/mUPQmuEudI2g-Lead-Quality-EI-Telecoms-MF-SPIE-Doha-Qatar
# 7
# https://wuzzuf.net/jobs/p/wjIBTmuyt6TK-Technical-Sales-Leader---DataAI-Automation---UAE-Gulf-Business-Machines-PND-Dubai-United-Arab-Emirates
# 8
# https://wuzzuf.net/jobs/p/M1j4QlVABNYi-TECHNICIAN---AC-Cargoes-Dubai-United-Arab-Emirates
# 9
# https://wuzzuf.net/jobs/p/Hj2NnvmAOKUi-Senior-Managing-Consultant-Advisors-Business-Development-Digital-OA--Mastercard-Dubai-United-Arab-Emirates
# 10
# https://wuzzuf.net/jobs/p/bU8h03XRKd2K-Senior-Analyst---Business-Application---Oracle-Fusion-Sidra-Medicine-Doha-Qatar
# 11
# https://wuzzuf.net/jobs/p/VUuohWB4YFla-Project-Manager-Contact-Center-Tazweed-Abu-Dhabi-United-Arab-Emirates
# 12
# https://wuzzuf.net/jobs/p/bKKxKbZ80Gb5-Metadata-Management-Lead-Charterhouse-Middle-East-Dubai-United-Arab-Emirates
# 13
# https://wuzzuf.net/jobs/p/ADcHknIrVrQQ-Senior-Sales-Account-Manager---Central-Governmentcopy-Giza-Arabia-Riyadh-Saudi-Arabia
# 14
# https://wuzzuf.net/jobs/p/fvjrKMSatHKu-Painter-Beach-Rotana-Abu-Dhabi-United-Arab-Emirates
# 15
# https://wuzzuf.net/jobs/p/WaUhO6Zvnko6-Sales-Account-Manager--HealthEduactioncopy-Giza-Arabia-Riyadh-Saudi-Arabia
# 1
# https://wuzzuf.net/jobs/p/82QfjyKqz0e5-Account-Manager-Facilities-Management-Soft-Services-Transguard-group-Dubai-United-Arab-Emirates
# 2
# https://wuzzuf.net/jobs/p/iTmaQVZs7DHK-Operations-Lead---IoT-Service-and-Call-Center-Parker-Connect-Dubai-United-Arab-Emirates
# 3
# https://wuzzuf.net/jobs/p/76bhJpXCZVLq-Senior-Electrical-Engineer-Wood-Dubai-United-Arab-Emirates
# 4
# https://wuzzuf.net/jobs/p/rNzTM8QJGwgm-Hybris-backend-Developer-Efada-Technology-Cairo-Egypt
# 5
# https://wuzzuf.net/jobs/p/vXQsLyN8Idwg-App-and-Web-developer-MFG-Cairo-Egypt
# 6
# https://wuzzuf.net/jobs/p/WUH7ftQK2CCF-Project-Manager-LINK-TSP-Cairo-Egypt
# 7
# https://wuzzuf.net/jobs/p/YmDJlsCIJz8B-IT-Help-Desk-MedVAlley-S-A-E-Cairo-Egypt
# 8
# https://wuzzuf.net/jobs/p/0OMRYENWp5tz-Senior-Backend-Nodejs-Developer---Mongo-DB-QARA-Cairo-Egypt
# 9
# https://wuzzuf.net/jobs/p/qKETr3Hv7Vs8-System-Administrator-MedVAlley-S-A-E-Cairo-Egypt
# 10
# https://wuzzuf.net/jobs/p/Trb5pHVrWhq8-IT-Administrator-Trans-World-Trading-Giza-Egypt
# 11
# https://wuzzuf.net/jobs/p/S8tFJ09FMnYL-IT-Technical-Support-Enable-Cairo-Egypt
# 12
# https://wuzzuf.net/jobs/p/pXckYGTY0ckH-System-Analyst-Cairo-Egypt
# 13
# https://wuzzuf.net/jobs/p/z5FQvKUgo4yz-SAP-FICO-Consultant-Nahdet-Misr-Publishing-Group-Giza-Egypt
# 14
# https://wuzzuf.net/jobs/p/XeUxQIaABKmw-Principal-Engineer---Information-Management-Petrofac-Dubai-United-Arab-Emirates
# 15
# https://wuzzuf.net/jobs/p/nCYry9aB04St-COUPA-Change-Manager-UHRS-Dubai-United-Arab-Emirates
# 1
# https://wuzzuf.net/jobs/p/IE53jlpEJ1yb-Life-science---Test-MF-akkodis-Dubai-United-Arab-Emirates
# 2
# https://wuzzuf.net/jobs/p/bTqtSCFNzmdX-Principal-Engineer---Metallurgy-Corrosion-Petrofac-Dubai-United-Arab-Emirates
# 3
# https://wuzzuf.net/jobs/p/sdESZwPsgovH-Football-Systems-Operator---Saudi-Arabia-Dammam-Hawk-Eye-Innovations-Ltd-Riyadh-Saudi-Arabia
# 4
# https://wuzzuf.net/jobs/p/57XuMYrd0AYP-Football-Systems-Operator---Saudi-Arabia-Jeddah-Hawk-Eye-Innovations-Ltd-Jeddah-Saudi-Arabia
# 5
# https://wuzzuf.net/jobs/p/vKHzm1qbyJCe-Project-Coordinator-Giza-Arabia-Systems-Cairo-Egypt
# 6
# https://wuzzuf.net/jobs/p/TAgI9yxe0ekv-Principal---Data-Services-Business-Development-OA--Mastercard-Dubai-United-Arab-Emirates
# 7
# https://wuzzuf.net/jobs/p/s24C4Z9C81z1-Senior-Communication-Engineer---Transmission-Giza-Arabia-Systems-Cairo-Egypt
# 8
# https://wuzzuf.net/jobs/p/iwVKkNLI3rVP-AV-Engineer-UrbaCon-Contracting-Trading-Company-Doha-Qatar
# 9
# https://wuzzuf.net/jobs/p/5LiFwSmVT0Eo-Sr-Custody-Exchange-Operations-Manager-Pantera-Dubai-United-Arab-Emirates
# 10
# https://wuzzuf.net/jobs/p/olvtI5OhKD7V-Java-Full-Stack-Developer-Dedalus-Cairo-Egypt
# 11
# https://wuzzuf.net/jobs/p/S6tpeZSJhVtL-NET-WPF-Developer-Premier-Services-and-Recruitment-Cairo-Egypt
# 12
# https://wuzzuf.net/jobs/p/ZQEZPpSkuapd-Net-React-Full-stack-Developer-Premier-Services-and-Recruitment-Cairo-Egypt
# 13
# https://wuzzuf.net/jobs/p/OyMOaTfkPH42-Net-Test-Analyst-Premier-Services-and-Recruitment-Cairo-Egypt
# 14
# https://wuzzuf.net/jobs/p/jKpxRFXXLZSx-Senior-Drupal-Developer-K-Line-Europe-Cairo-Egypt
# 15
# https://wuzzuf.net/jobs/p/q7pcANTfdkdY-Senior-Technical-Recruiter-Link-Datacenter-Cairo-Egypt
# 1
# https://wuzzuf.net/jobs/p/BhWrVbLsRnTW-Senior-Java-Developer-WSC-Giza-Egypt
# 2
# https://wuzzuf.net/jobs/p/DXkYKxsetbJ2-Selenium-Automation-Tester-Yespays-Cairo-Egypt
# 3
# https://wuzzuf.net/jobs/p/1Fbg9rXEEf5J-Senior-Analyst---Financial-Planning-Control-flydubai-Dubai-United-Arab-Emirates
# 4
# https://wuzzuf.net/jobs/p/XqUErYvd7pn3-Senior-Process-Engineer---Hydrogen-John-Wood-Group-PLC-Dubai-United-Arab-Emirates
# 5
# https://wuzzuf.net/jobs/p/ibPcX7DcNqjx-Inventory-Analyst-Etihad-Airways-Abu-Dhabi-United-Arab-Emirates
# 6
# https://wuzzuf.net/jobs/p/4siqeikzPTBk-Junior-IT-Help-Desk-Nacita-Cairo-Egypt
# 7
# https://wuzzuf.net/jobs/p/9KlPIwN4xk2K-Senior-Recruiter-Wood-Dubai-United-Arab-Emirates
# 8
# https://wuzzuf.net/jobs/p/LilHItgfQwHB-IT-System-Admin-Delta-Egypt-For-Lighting-Cairo-Egypt
# 9
# https://wuzzuf.net/jobs/p/mepB7iqxxfPI-Maintenance-Technician---Central-Production-Facility---Kuwait-Alshaya-Group-Kuwait-City-Kuwait
# 10
# https://wuzzuf.net/jobs/p/U1TYAVljd7Xy-Virtual-Project-Management-Internship-Qureos-Cairo-Egypt
# 11
# https://wuzzuf.net/jobs/p/XHD79lEU0uc6-Team-Leader---Guest-Services---Russian-Speaker-Rose-Rayhaan-by-Rotana-Dubai-United-Arab-Emirates
# 12
# https://wuzzuf.net/jobs/p/rVcIIfLR6DnG-Team-Leader---Guest-Services-Centro-Capital---Doha-Doha-Qatar
# 13
# https://wuzzuf.net/jobs/p/5UQuU0hdF0j1-AC-Technician-Al-Marwa-Rayhaan-by-Rotana-Riyadh-Saudi-Arabia
# 14
# https://wuzzuf.net/jobs/p/7Z5nJcElyUrM-Liferay-DeveloperRemote-Xische-Co-Dubai-United-Arab-Emirates
# 15
# https://wuzzuf.net/jobs/p/jWktCnIS2PUW-Support-Services-Analyst-II-Yanbu-Aramco-Sinopec-Refining-Company-YASREF-Yanbu-Saudi-Arabia
# 1
# https://wuzzuf.net/jobs/p/zXdGdDOVM3a0-Operations-Director-PV-Central-Eastern-Cluster-NOMAC-Jeddah-Saudi-Arabia
# 2
# https://wuzzuf.net/jobs/p/MODuWwl3gmEQ-HR-Consultant-Professional-Recruitment-Riyadh-Saudi-Arabia
# 3
# https://wuzzuf.net/jobs/p/dEssSCp7d2hs-IT-Manager-Cairo-Egypt
# 4
# https://wuzzuf.net/jobs/p/LIYRAKxfsSHi-Product-Manager-Bydotpy-Cairo-Egypt
# 5
# https://wuzzuf.net/jobs/p/Zqg1BW0487jj-IT-Digital-Transformation-Manager-Cairo-Egypt
# 6
# https://wuzzuf.net/jobs/p/lNn4OUJAGZGr-Technical-Operations-Engineer-Cashcall-Cairo-Egypt
# 7
# https://wuzzuf.net/jobs/p/SkNULXyXsKsD-Senior-Infrastructure-Engineer-Lumin-Giza-Egypt
# 8
# https://wuzzuf.net/jobs/p/DIpY4RMdDBTJ-Senior-NET-Developer-SSC-Egypt-Cairo-Egypt
# 9
# https://wuzzuf.net/jobs/p/ZIgW095hZZwV-Customer-Support-Representative-International-Advanced-Cairo-Egypt
# 10
# https://wuzzuf.net/jobs/p/4S6AENTvhogF-JRIT-Support-ENOVA-Facilities-Management-Cairo-Egypt
# 11
# https://wuzzuf.net/jobs/p/LG1o7zpozaxF-Senior-Business-Analyst-Cairo-Egypt
# 12
# https://wuzzuf.net/jobs/p/YDTwwKBU6dKM-Front-End-Developer-WSC-Giza-Egypt
# 13
# https://wuzzuf.net/jobs/p/SldzUthH6TUe-React-Native-UI-Software-Engineer-Callvita-Cairo-Egypt
# 14
# https://wuzzuf.net/jobs/p/CPk3r3obDKOQ-Full-Stack-Software-Engineer-Callvita-Cairo-Egypt
# 15
# https://wuzzuf.net/jobs/p/SXL4JOK7WJn2-Wordpress-Developer-New-Energy-EV-Cairo-Egypt
# 1
# https://wuzzuf.net/jobs/p/vvToKTfgVxoG-Business-Analyst-Informatique-Education-Cairo-Egypt
# 2
# ...
# 12
# https://wuzzuf.net/jobs/p/nZ8bxGUnyX0I-IT-Officer-British-Council-Cairo-Egypt
# 13
# https://wuzzuf.net/jobs/p/eDN2INrF2Nwu-Devops-Engineer-WSC-Giza-Egypt
# 14
# https://wuzzuf.net/jobs/p/22rIS0lbbeFp-Field-support-Technician-Multi-Level-Group-MLG-Cairo-Egypt
# 15
# https://wuzzuf.net/jobs/p/QsdhNOpH6kFR-Senior-AI-Engineer-Ejada-Cairo-Egypt
# 1
# https://wuzzuf.net/jobs/p/Ikb9g48l2Dw8-Senior-Backend-Developer-TensorGraph-Cairo-Egypt
# 2
# https://wuzzuf.net/jobs/p/l3Swe7bCmroN-Senior-Software-Developer---Large-e-commerce-Store-6-of-October-city-Pillars-Cairo-Egypt
# 3
# https://wuzzuf.net/jobs/p/oHJ8Wz4dBPV6-Office-Assistant-Secretary-Hayati-SRL-Cairo-Egypt
# 4
# https://wuzzuf.net/jobs/p/BqPdGM2pIxIA-Senior-Front-End-Developer-Blockchain-Perfect-Presentation-Giza-Egypt
# 5
# https://wuzzuf.net/jobs/p/bpm78TPZqx3e-Junior-Software-Tester-Aliaict-Cairo-Egypt
# 6
# https://wuzzuf.net/jobs/p/46p5Ge1U2oxu-Senior-Front-end-Developer-Angular-FlairsTech-Cairo-Egypt
# 7
# https://wuzzuf.net/jobs/p/NtAjktm83woM-Senior-Flutter-Developer-Cairo-Egypt
# 8
# https://wuzzuf.net/jobs/p/8TalHvsGexK4-Senior-Oracle-Apps-Developer-Apex-EVA-Cosmetics-Giza-Egypt
# 9
# https://wuzzuf.net/jobs/p/cja7lxzJlL8V-Technical-Support-Engineer-Al-Rabat-Cairo-Egypt
# 10
# https://wuzzuf.net/jobs/p/YoWmNVf98X4H-IoT-Software-Engineer-Interact-Technology-Solutions-Cairo-Egypt
# 11
# https://wuzzuf.net/jobs/p/ricg2ntK8E6K-IT-Help-Desk-Specialist-Majorel-Egypt-Alexandria-Egypt
# 12
# https://wuzzuf.net/jobs/p/4853I4MSE2rG-Senior-Network-Security-Engineer-Interact-Technology-Solutions-Cairo-Egypt
# 13
# https://wuzzuf.net/jobs/p/4HQc05gvJWDw-UIUX-Designer-On-Site-Union-Coop-Giza-Egypt
# 14
# https://wuzzuf.net/jobs/p/2UkLtrZhIblD-UI-UX-Designer-Dafa-Giza-Egypt
# 15
# https://wuzzuf.net/jobs/p/8poIgwTMvCWI-IT-Support-Engineer-Al-Soug-Cashi-Cairo-Egypt
# 1
# https://wuzzuf.net/jobs/p/VDjzMYeJA0xy-Technical-Support-Engineer-Bevatel-Giza-Egypt
# 2
# https://wuzzuf.net/jobs/p/rYFWh7Ilhiac-Application-Support-Engineer-3S-Software-Cairo-Egypt
# 3
# https://wuzzuf.net/jobs/p/VcfWW4UkSujr-Network-Engineer-Efada-Technology-Cairo-Egypt
# 4
# https://wuzzuf.net/jobs/p/xDeBsnQxHakZ-Microsoft-Exchange-Administrator-A1Softech-Cairo-Egypt
# 5
# https://wuzzuf.net/jobs/p/z84FVDgGTamv-Global-Active-Directory-Expert-Efada-Technology-Giza-Egypt
# 6
# https://wuzzuf.net/jobs/p/MCqwzX1GxrQF-Cloud-Solutions-Sales-Associate-Giza-Egypt
# 7
# https://wuzzuf.net/jobs/p/oFZEyIjou2QC-Cloud-Solutions-Sales-Manager-Giza-Egypt
# 8
# https://wuzzuf.net/jobs/p/VsUeMnPzkDCz-IT---System-Administration-Specialist-Premium-Card-Giza-Egypt
# 9
# https://wuzzuf.net/jobs/p/AgsWu5pgnkjB-Financial-Consultant-Dynamicslink-Cairo-Egypt
# 10
# https://wuzzuf.net/jobs/p/qK4gtqXQ4rS2-Application-Support-Engineer-Egypt-Kuwait-Holding-Giza-Egypt
# 11
# https://wuzzuf.net/jobs/p/oHSDURWuCFRO-Senior-Python-Developer-WORLD-OF-BUSINESS-Sidon-Lebanon
# 12
# https://wuzzuf.net/jobs/p/GmkOqY0Qzoi4-Senior-Backend-Developer-YOUXEl-Technology-Cairo-Egypt
# 13
# https://wuzzuf.net/jobs/p/tTCAVRc833oK-Full-Stack-Developer-NET-core-Angular-8--Part-Time-Cairo-Egypt
# 14
# https://wuzzuf.net/jobs/p/0XDdLLS1SyG7-Senior-Angular-Developer-International-Advanced-Cairo-Egypt
# 15
# https://wuzzuf.net/jobs/p/DCnm7UXYL7lT-Full-Stack-Java-Developer-Giza-Egypt
# 1
# https://wuzzuf.net/jobs/p/1y9DYgODe3Hx-System-Engineer-Global-Brands-Cairo-Egypt
# 2
# https://wuzzuf.net/jobs/p/aaznz33kLs9K-Software-Technical-Team-Leader-Softec-Technologies-Cairo-Egypt
# 3
# https://wuzzuf.net/jobs/p/B3jHSlmmBLJQ-Senior-Python-Developer-TensorGraph-Cairo-Egypt
# 4
# https://wuzzuf.net/jobs/p/KwoLFItXOhP2-Senior-Node-JS-Developer-TensorGraph-Cairo-Egypt
# 5
# https://wuzzuf.net/jobs/p/FimOZ30Srmez-Digital-Transformation-Team-Leader-Cairo-Egypt
# 6
# https://wuzzuf.net/jobs/p/c9ogVmDU3q29-Software-Developer---Backend---Senior-Cairo-Egypt
# 7
# https://wuzzuf.net/jobs/p/7D5CQt5JrJi7-Linux-Systems-Administrator-Al-Ahly-capital-holding---Al-Ahly-Tamkeen-Cairo-Egypt
# 8
# https://wuzzuf.net/jobs/p/11YgxC6XpWfv-ERP-implementer-taknia-systems-Qalubia-Egypt
# 9
# https://wuzzuf.net/jobs/p/IDzHAS3pBVbE-Development-Tech-Leader-Bevatel-Giza-Egypt
# 10
# https://wuzzuf.net/jobs/p/m3laIb3Yvvrr-Technical-Recruiter-Ejada-Cairo-Egypt
# 11
# https://wuzzuf.net/jobs/p/RorwBPlTHbsA-Team-Leader-Senior-Full-Stack-PHP-Drupal-Developer-Orange-Studio-Cairo-Egypt
# 12
# https://wuzzuf.net/jobs/p/waq9gbWo3zu6-Senior-SEO-Senior-Search-Engine-Optimization-Waseet-net-Cairo-Egypt
# 13
# https://wuzzuf.net/jobs/p/IWWlxKX66JpF-Senior-Devops-Engineer-Izam-inc-Giza-Egypt
# 14
# https://wuzzuf.net/jobs/p/IxCWA6GOPt4l-Full-Stack-Web-Developer---PHP-Orange-Studio-Cairo-Egypt
# 15
# https://wuzzuf.net/jobs/p/EKA058J5fs7I-Full-Stack-Developer-GoodsMart-Cairo-Egypt
# 1
# https://wuzzuf.net/jobs/p/bijh43lEbpdZ-Web-Developer-Target-Recruitment-HR-Solutions-Cairo-Egypt
# 2
# https://wuzzuf.net/jobs/p/hRcwtFhOrl9E-Network-Voice-Engineer-Interact-Technology-Solutions-Cairo-Egypt
# 3
# https://wuzzuf.net/jobs/p/X6xFX41BZsPf-IT-Specialist-Micro-Engineering-Cairo-Egypt
# 4
# https://wuzzuf.net/jobs/p/UUbnn3MUw3xa-Front-End-Developer-Angular-Horizon-Cairo-Egypt
# 5
# https://wuzzuf.net/jobs/p/XNwNyGEwsMRt-Front-End-Developer-Indegree-Dakahlia-Egypt
# 6
# https://wuzzuf.net/jobs/p/nlaiOqIFBREc-UI-UX-Designer-Indegree-Dakahlia-Egypt
# 7
# https://wuzzuf.net/jobs/p/SYqpVoWmZ4uT-Senior-PHP-laravel-developer-Loc-Camp-Giza-Egypt
# 8
# https://wuzzuf.net/jobs/p/tstGZx38bWGM-IT-Specialist-Hands-of-Hope-Physical-Therapy-Wellness-Cairo-Egypt
# 9
# https://wuzzuf.net/jobs/p/uZwhEWIpryCq-Technical-Support-Engineer-Tier-1-Ulemt-Cairo-Egypt
# 10
# https://wuzzuf.net/jobs/p/248KNmOfJUPZ-UIUX-Web-Designer-Cairo-Egypt
# 11
# https://wuzzuf.net/jobs/p/5Y8AJH7A3Ax9-Front-End-Developer---Vuejs-Remote-Work-Cairo-Egypt
# 12
# https://wuzzuf.net/jobs/p/bmz8H28Oqvs1-SAP-Junior-Develop-LABS-Cairo-Egypt
# 13
# https://wuzzuf.net/jobs/p/2kutRDNDmVEp-Group-ICT-Infrastructure-and-Service-Desk-Section-Head-Decorative-Glass-And-Arab-Union-Glass-Group-Cairo-Egypt
# 14
# https://wuzzuf.net/jobs/p/L642aIFty8qG-Senior-Devops-Engineer-Cairo-Egypt
# 15
# https://wuzzuf.net/jobs/p/JKveN5lKVpgs-Senior-Digital-Transformation-Advisor-Professional-Services---Sales-Global-Brands-Cairo-Egypt
# 1
# https://wuzzuf.net/jobs/p/0zCLwZe5OzY2-Technical-Project-Manager-Data-Science-Giza-Egypt
# 2
# https://wuzzuf.net/jobs/p/BsL236mZ6uen-System-Administrator-Egypt-Kuwait-Holding-Giza-Egypt
# 3
# https://wuzzuf.net/jobs/p/ly0PBAbLTvHm-Quality-Control-Engineer-Samaya-Electronics-Egypt-LTD-Cairo-Egypt
# 4
# https://wuzzuf.net/jobs/p/czFYWEvaDkZD-Information-Security-Specialist-Xceed-Contact-Center-Cairo-Egypt
# 5
# https://wuzzuf.net/jobs/p/o3ZyIfw8u9U2-IT-System-Engineer-VMware-Infrastructure-Efada-Technology-Cairo-Egypt
# 6
# https://wuzzuf.net/jobs/p/WPrYMnNfrsvK-Technical-Support-Rashideen-Egypt-for-Trade-Gharbia-Egypt
# 7
# https://wuzzuf.net/jobs/p/cagDu1qnYJ0q-AX-Technical-Consultant-Elabd-Foods-Giza-Egypt
# 8
# https://wuzzuf.net/jobs/p/HLTktSsPMXk0-Senior-ERP-Engineer-AL-MASHARIQ-Cairo-Egypt
# 9
# https://wuzzuf.net/jobs/p/1WB150x7YSiL-IT-Help-Desk-Specialist-Elite-Education-Group-Cairo-Egypt
# 10
# https://wuzzuf.net/jobs/p/HOaEt97xdhWy-Banking-Business-Operations-Engineer-Fawry-for-Banking-Technology-and-Electronic-Payments-S-A-E-Giza-Egypt
# 11
# https://wuzzuf.net/jobs/p/kn9JtSuBkqrW-First-Level-Technical-Support-Engineer-3D-Diagnostix-Cairo-Egypt
# 12
# https://wuzzuf.net/jobs/p/uEKBYA0j0GOc-Second-Level-Technical-Support-Engineer-3D-Diagnostix-Cairo-Egypt
# 13
# https://wuzzuf.net/jobs/p/VKcVYBqfSzax-Tech-Lead-Cairo-Egypt
# 14
# https://wuzzuf.net/jobs/p/R0r78MvNhvO4-Front-End-Developer-Thaka-International-Cairo-Egypt
# 15
# https://wuzzuf.net/jobs/p/UmAAj3WFm2jZ-Web-Development-NET-Tech-Lead-Seoudi-Supermarket-Giza-Egypt
# 1
# https://wuzzuf.net/jobs/p/8EOHl3TpGo4B-UIUX-Designer-Arabia-for-Information-Technology-Cairo-Egypt
# 2
# https://wuzzuf.net/jobs/p/Usane1H8h8YE-System-Administrator-Talaat-Moustafa-Group-Giza-Egypt
# 3
# https://wuzzuf.net/jobs/p/IE67jIbOjWj6-Senior-Odoo-developer-Bluebell-Pharmaceuticals-Cairo-Egypt
# 4
# https://wuzzuf.net/jobs/p/eoQOoMZqPZ4i-Senior-Full-Stack-ReactNodeJSSQL-Developer-Cairo-Egypt
# 5
# https://wuzzuf.net/jobs/p/SUuiSGXK76ON-Senior-Full-Stack-Developer-net-core--angular-A1Softech-Cairo-Egypt
# 6
# https://wuzzuf.net/jobs/p/KnzZtnXHOQ7U-IT-Systems-Engineer-Grifols-Egypt-for-Plasma-Derivatives-Cairo-Egypt
# 7
# https://wuzzuf.net/jobs/p/bIt7ubXYrQoP-Software-Developer---Front-End-Cairo-Egypt
# 8
# https://wuzzuf.net/jobs/p/nZiZmmrXNVnV-Senior-Linux-System-Admin-3-years-experience-3D-Diagnostix-Cairo-Egypt
# 9
# https://wuzzuf.net/jobs/p/uqDYkkpi6Q3Y-Junior-Angular-Front-end-Developer-StudentGator-Giza-Egypt
# 10
# https://wuzzuf.net/jobs/p/qhGefdBFRitF-Software-Sales-Engineer-Cairo-Egypt
# 11
# https://wuzzuf.net/jobs/p/ya0N79VbUNs1-Senior-Business-Analyst-Coral-Technology-Cairo-Egypt
# 12
# https://wuzzuf.net/jobs/p/WZuXOwvLaOSl-BI-Developer-GPS-Cairo-Egypt
# 13
# https://wuzzuf.net/jobs/p/rOW0z2VonoXb-Quality-Assurance-A1Softech-Cairo-Egypt
# 14
# https://wuzzuf.net/jobs/p/sf4yLXjaGJU7-IT-Help-Desk-LABS-Cairo-Egypt
# 15
# https://wuzzuf.net/jobs/p/wh68KzekJVsB-IT-Help-Desk-Specialist-Sutherland-Alexandria-Egypt
# 1
# https://wuzzuf.net/jobs/p/1YbnuxrcrLjK-Senior-Information-Security-Engineer-Coral-Technology-Cairo-Egypt
# 2
# https://wuzzuf.net/jobs/p/l87m3Fk5XsnN-SAP-Basis-Specialist-Rashideen-Egypt-for-Trade-Cairo-Egypt
# 3
# https://wuzzuf.net/jobs/p/mOEimOmgIHOT-Junior-Sales-Account-Manager-Dynamicslink-Cairo-Egypt
# 4
# https://wuzzuf.net/jobs/p/Dm4E0NvkVPII-Pre-Sales-Engineer-Interact-Technology-Solutions-Cairo-Egypt
# 5
# https://wuzzuf.net/jobs/p/NnYG5j0fWM6A-Senior-PHPLaravel-Developer-Edentech-Cairo-Egypt
# 6
# https://wuzzuf.net/jobs/p/0FhYOpVuJHEo-Business-Analyst-Lead-Lumin-Giza-Egypt
# 7
# https://wuzzuf.net/jobs/p/9ahJypNijuSj-Web-Designer-Front-End-Developer---WordPress-INTERNET-SOLUTIONS-Giza-Egypt
# 8
# https://wuzzuf.net/jobs/p/FyXuvkTo9zsI-Search-Engine-Optimization-Specialist-INTERNET-SOLUTIONS-Giza-Egypt
# 9
# https://wuzzuf.net/jobs/p/ipFzPaCAmEPW-Senior-React-Native-Developer-TechJump-Alexandria-Egypt
# 10
# https://wuzzuf.net/jobs/p/T7Lu0yFvmfol-Tech-Lead-net-Angular-Cairo-Egypt
# 11
# https://wuzzuf.net/jobs/p/01J6peWozp3j-Senior-IT-Specialist-FlairsTech-Cairo-Egypt
# 12
# https://wuzzuf.net/jobs/p/fr9J5blYlAsV-Software-Engineering-Manager-Cairo-Egypt
# 13
# https://wuzzuf.net/jobs/p/Z4kc0gFLsEnq-IT-Deputy-Manager---Minya-Sohag-VFS-Global-Egypt-Minya-Egypt
# 14
# https://wuzzuf.net/jobs/p/Yyd3XFlwBtyZ-Senior-Odoo-Implementer-National-Technology-Cairo-Egypt
# 15
# https://wuzzuf.net/jobs/p/NLsELhwcC2SN-Project-Manager-Cairo-Egypt
# 1
# https://wuzzuf.net/jobs/p/r91IkN5q5hTx-IT-System-Administrator-Selah-ElTelmeez-For-Publishing-printing-Cairo-Egypt
# 2
# https://wuzzuf.net/jobs/p/TUsx5j1h44bF-IT-Help-Desk-Specialist-Webhelp-Cairo-Egypt
# 3
# https://wuzzuf.net/jobs/p/KUf5kB7Ow7OG-Software-Business-Analyst-Dexef-Monufya-Egypt
# 4
# https://wuzzuf.net/jobs/p/pf2Jmz7ebXG7-Software-Sales-Representative-Selftreat-Cairo-Egypt
# 5
# https://wuzzuf.net/jobs/p/S3bWx71U8SOS-Lead-Product-Manager-Human-Quality-Cairo-Egypt
# 6
# https://wuzzuf.net/jobs/p/2Zz7Sk2nwmTt-Cyber-Security-Engineer-Itechs-Cairo-Egypt
# 7
# https://wuzzuf.net/jobs/p/6cuAR9gVw2H6-Senior-Software-Quality-Engineer-Human-Quality-Cairo-Egypt
# 8
# https://wuzzuf.net/jobs/p/UhjigXCXsUJU-UX-Lead-Human-Quality-Cairo-Egypt
# 9
# https://wuzzuf.net/jobs/p/2slCJts4ck4i-Network-Security-Engineer-Aman-Holding-Cairo-Egypt
# 10
# https://wuzzuf.net/jobs/p/hLNBoDmH06mo-IT-Executive-VFS-Global-Egypt-Giza-Egypt
# 11
# https://wuzzuf.net/jobs/p/qUuBYgHxYX0z-IT-Deputy-Manager---Alexandria-VFS-Global-Egypt-Alexandria-Egypt
# 12
# https://wuzzuf.net/jobs/p/miCPoMuGPEcd-Odoo-Developer-National-Technology-Cairo-Egypt
# 13
# https://wuzzuf.net/jobs/p/DjqEnvjZ1Qvf-Software-Developer-Full-Stack-Programming-Staron-Egypt-Cairo-Egypt
# 14
# https://wuzzuf.net/jobs/p/mD3k3R6blo9p-Business-Analyst-Egabi-FSI-Cairo-Egypt
# 15
# https://wuzzuf.net/jobs/p/EtmVMZZwgBDw-Business-Analyst-Amasi-Cairo-Egypt
# 1
# https://wuzzuf.net/jobs/p/u3Sh4WuBNptu-Infrastructure-Sales-Account-Manager-IT-Cores-Cairo-Egypt
# 2
# https://wuzzuf.net/jobs/p/64Ymd05QHVmk-Senior-Front-End-Developer-ZE-LOGIC-Giza-Egypt
# 3
# https://wuzzuf.net/jobs/p/N3H6TP2sLY53-Senior-Full-Stack-Developer-Cairo-Egypt
# 4
# https://wuzzuf.net/jobs/p/ENcMwD24Nhxq-Experienced-Front-end-Developer-React-Js-React-native-Yespays-Cairo-Egypt
# 5
# https://wuzzuf.net/jobs/p/Cb6ncQON6KTM-Frontend-Developer-Perfect-Presentation-Giza-Egypt
# 6
# https://wuzzuf.net/jobs/p/yVdBHckp6XlY-Business-Development-Engineer-Brilliant-Engineering-Giza-Egypt
# 7
# https://wuzzuf.net/jobs/p/udGsV4hsF95v-senior-outsystems-developer-Centione-Cairo-Egypt
# 8
# https://wuzzuf.net/jobs/p/yhLMEnscsQu4-Xamarin-Developer-FlairsTech-Cairo-Egypt
# 9
# https://wuzzuf.net/jobs/p/zFAOWyTONGOf-Odoo-Implementer-National-Technology-Cairo-Egypt
# 10
# https://wuzzuf.net/jobs/p/mv9wXUgb5bES-Senior-UIUX-Designer-Amasi-Cairo-Egypt
# 11
# https://wuzzuf.net/jobs/p/4sCsLfQGPiLo-Data-Engineer-UMX-Studio-Giza-Egypt
# 12
# https://wuzzuf.net/jobs/p/gM3u6Iaf5EnG-Specialist-IT-Support-ESLSCA-University-Cairo-Egypt
# 13
# https://wuzzuf.net/jobs/p/BNXVsDeL3lzY-Senior-Ruby-on-Rails-International-Advanced-Cairo-Egypt
# 14
# https://wuzzuf.net/jobs/p/Mhh6FBneJ27W-Quality-control-Dolf-Cairo-Egypt
# 15
# https://wuzzuf.net/jobs/p/5QcrCZQcnvLX-Senior-Ruby-Developer-Bevatel-Giza-Egypt
# 1
# https://wuzzuf.net/jobs/p/51hFz04VzAiQ-Sales-Specialist-Digital-Marketing-and-Software-Solutions-Bevatel-Giza-Egypt
# 2
# https://wuzzuf.net/jobs/p/q2wT3dWBMDea-System-AdministratorDevOps-Engineer-Safa-Soft-Cairo-Egypt
# 3
# https://wuzzuf.net/jobs/p/hDQ64wU2Brlh-Java-Developer---Back-End-Ebla-Cairo-Egypt
# 4
# https://wuzzuf.net/jobs/p/j9r5RobbaBnl-Technical-Lead-Full-Stack-webSTDY-Giza-Egypt
# 5
# https://wuzzuf.net/jobs/p/NCnklBAMv3o9-Software-Tester-webSTDY-Giza-Egypt
# 6
# https://wuzzuf.net/jobs/p/DkWD6rKI3Baf-Senior-PHP-Laravel-Developer-webSTDY-Giza-Egypt
# 7
# https://wuzzuf.net/jobs/p/1ngRMgwzzXin-Project-Manager-ZINAD-IT-Giza-Egypt
# 8
# https://wuzzuf.net/jobs/p/Ofem37sEfRtT-Application-Developer-Unity-3D-programmer-Cairo-Egypt
# 9
# https://wuzzuf.net/jobs/p/YDPwULNADnEz-Senior-Full-Stack-Developer-23012-Ditech-Egypt-Cairo-Egypt
# 10
# https://wuzzuf.net/jobs/p/SS9rUnYTEQ77-Application-Support-Engineer23013-Ditech-Egypt-Cairo-Egypt
# 11
# https://wuzzuf.net/jobs/p/lodw8hmmQimc-Senior-Back-end-Developer-Magento-Seoudi-Supermarket-Giza-Egypt
# 12
# https://wuzzuf.net/jobs/p/BsNbHt9G8aPu-Solution-Architect---Part-Time-Lumin-Giza-Egypt
# 13
# https://wuzzuf.net/jobs/p/ulXaSHoZvfcz-Sr-Net-Developer-egabi-solutions-Cairo-Egypt
# 14
# https://wuzzuf.net/jobs/p/T4ptqMIz5C9a-QA-Engineer-egabi-solutions-Cairo-Egypt
# 15
# https://wuzzuf.net/jobs/p/IlMhHofsihoz-Unity-Developer--Part-Time-RDI-Giza-Egypt
# 1
# https://wuzzuf.net/jobs/p/BMp4BFaD0Gkt-Senior-Python-Django-Developer--Part-Time-RDI-Giza-Egypt
# 2
# https://wuzzuf.net/jobs/p/S6BY6Ox6IpPg-Oracle-Fusion-Technical-Consultant-Ejada-Cairo-Egypt
# 3
# https://wuzzuf.net/jobs/p/PPVQnxLUWLUR-Senior-NET-Developer-with-Mashup-Development-Expertise-Riyadh-Saudi-Arabia
# 4
# https://wuzzuf.net/jobs/p/3d8PYhp1WpLD-Senior-Qlik-Sense-Developer-with-NPrinting-Alerting-Expertise-Riyadh-Saudi-Arabia
# 5
# https://wuzzuf.net/jobs/p/SWSn6LGbe3Oi-IT-Specialist-Al-Soug-Cashi-Giza-Egypt
# 6
# https://wuzzuf.net/jobs/p/fRwTTlPfghLR-Android-Developer-Rowaad-Cairo-Egypt
# 7
# https://wuzzuf.net/jobs/p/4LJf6u2OKhqA-Pre-Sales-Engineer-ZINAD-IT-Giza-Egypt
# 8
# https://wuzzuf.net/jobs/p/hfHF7doGEito-IT-Specialist-Advansys-for-Trading-Contracting-Cairo-Egypt
# 9
# https://wuzzuf.net/jobs/p/MUyh7j1ihafH-Senior-Frontend-Developer-URANIUM-Cairo-Egypt
# 10
# https://wuzzuf.net/jobs/p/RYHiieyBd2G8-Microsoft-SharePoint-and-Power-Platform-Development-Lead-One-Year-Contract-Dreem-Mashreq-Foods-Alexandria-Egypt
# 11
# https://wuzzuf.net/jobs/p/p7p9XdxERTLv-Digital-Sales-Executive-Be-Group-Cairo-Egypt
# 12
# https://wuzzuf.net/jobs/p/fWixLu6i3n6N-Service-Desk-Engineer-ITS-Cairo-Egypt
# 13
# https://wuzzuf.net/jobs/p/LehmVbzGxpJo-Quality-Assurance-Specialist-ITS-Cairo-Egypt
# 14
# https://wuzzuf.net/jobs/p/m1QfJusTBctP-IT-Help-Desk-Coordinator-FlexFilms-Egypt-Giza-Egypt
# 15
# https://wuzzuf.net/jobs/p/A3TpXtV5wGYe-Software-AnalystTester-Fresh---Alexandria-Arabic-Localizer-Alexandria-Egypt

# %%
errors
# Out:
# ['https://wuzzuf.net/internship/IdwWnYHUoNvp-PHP-Developer-Internship---Remote-Elev8Assessments-Giza-Egypt',
#  'https://wuzzuf.net/internship/FfEIWW2gAFYu-Quality-Control-Engineer-Internship-WUZZUF-Cairo-Egypt',
#  'https://wuzzuf.net/internship/1qa8eZCttPig-Backend-Developer-Internship-WUZZUF-Cairo-Egypt',
#  'https://wuzzuf.net/internship/VR1mvWphjOJY-It-Help-Desk-Intern-Sutherland-Cairo-Egypt']

# %%
cerrors
# Out:
# ['https://wuzzuf.net/jobs/careers/Nakheel-Egypt-85138']

# %%
# for testing
browser = webdriver.Chrome()
browser.get(cerrors[0])
html_content = browser.page_source
jsoup = bsp(html_content, "html.parser")
browser.quit()

# %%
job_posting_data.to_csv("job_posting.csv", sep=',', encoding='utf-8', index=False)
job_posting_data
# Out:
#                                          job_title  \
# 0                             Full Stack Developer
# 1             Senior Backend Developer (.NET Core)
# 2                            Dot Net Web Developer
# 3                   Full Stack wordpress Developer
# 4                 Senior Odoo Developer - (Onsite)
# ...                                            ...
# 1940                       Digital Sales Executive
# 1941                         Service Desk Engineer
# 1942                  Quality Assurance Specialist
# 1943                      IT Help Desk Coordinator
# 1944  Software Analyst/Tester (Fresh) - Alexandria
#
#                                             description  \
# 0     full stack Developer using php 3+Yrs of Exp We...
# 1      Review, test and debug team members’ code Des...
# 2     Handle web-based systems Work on Microsoft sta...
# 3     We Are looking for Experienced & professional ...
# 4     Responsibilities : Understand customer require...
# ...                                                 ...
# 1940  Establish and maintain current client and pote...
# 1941  Testing and analyzing IT system and software p...
# 1942  Regarding Internal Audit: To follow up with au...
# 1943  Serve as the first point of contact for employ...
# 1944  A leading Software Solutions Companies in Alex...
#
#                                            requirements   post_date viewed  \
# 0                                                        2023-11-01   None
# 1     Work experience as a Senior Java Developer or ...  2023-11-01   None
# 2     Bachelor Degree in Computer Sciences, Software...  2023-11-01   None
# 3     Proven experience in full-stack development wi...  2023-11-01   None
# 4     5-7 years of work experience of Odoo/ Open ERP...  2023-11-01   None
# ...                                                 ...         ...    ...
# 1940  Experience in outdoor sales in any service fie...  2023-09-01     29
# 1941  Bachelor's degree in computer science, informa...  2023-09-01      5
# 1942   Organizational and planning Communication Exc...  2023-09-01      0
# 1943  Bachelor’s degree in computer science, compute...  2023-09-01     72
# 1944  Gender: Female [Veiled]No Experience is Requir...  2023-09-01     86
#
#      considered experience_min experience_max  \
# 0          None              1              2
# 1          None              5              7
# 2          None              2           None
# 3          None              2              5
# 4          None              7             10
# ...         ...            ...            ...
# 1940          0              1              2
# 1941          0              2              3
# 1942          0              2              5
# 1943         24              1              3
# 1944         16              0              3
#
#                                  career_level    education_level salary_min  \
# 0                   Experienced (Non-Manager)               None       None
# 1                   Experienced (Non-Manager)               None       None
# 2     Entry Level (Junior Level / Fresh Grad)  Bachelor's Degree       None
# 3                   Experienced (Non-Manager)               None       None
# 4                   Experienced (Non-Manager)  Bachelor's Degree      80000
# ...                                       ...                ...        ...
# 1940  Entry Level (Junior Level / Fresh Grad)  Bachelor's Degree       None
# 1941                Experienced (Non-Manager)               None       None
# 1942                Experienced (Non-Manager)               None       None
# 1943  Entry Level (Junior Level / Fresh Grad)  Bachelor's Degree       None
# 1944  Entry Level (Junior Level / Fresh Grad)  Bachelor's Degree       None
#
#      salary_max  hidden_salary gender  vacancies           company country  \
# 0          None           True   None          1       Sketch-tech   Egypt
# 1          None           True   None          1      Confidential   Egypt
# 2          None           True      M          5             Tidal   Egypt
# 3          None           True   None          1        Osolutions   Egypt
# 4        100000          False   None          3      Confidential   Egypt
# ...         ...            ...    ...        ...               ...     ...
# 1940       None           True   None          4          Be Group   Egypt
# 1941       None           True   None          1               ITS   Egypt
# 1942       None           True   None          1               ITS   Egypt
# 1943       None           True   None          1   FlexFilms Egypt   Egypt
# 1944       None           True      F          3  Arabic Localizer   Egypt
#
#             city        district
# 0     Alexandria            Glim
# 1          Cairo            None
# 2          Cairo            None
# 3          Cairo        Sheraton
# 4          Cairo       New Nozha
# ...          ...             ...
# 1940       Cairo       Nasr City
# 1941       Cairo       Nasr City
# 1942       Cairo       Nasr City
# 1943        Giza  6th of October
# 1944  Alexandria     San Stefano
#
# [1945 rows x 19 columns]

# %%
job_posting_type_data.to_csv("job_posting_type.csv", sep=',', encoding='utf-8', index=False)
job_posting_type_data
# Out:
#                company                                     job_title country  \
# 0          Sketch-tech                          Full Stack Developer   Egypt
# 1         Confidential          Senior Backend Developer (.NET Core)   Egypt
# 2                Tidal                         Dot Net Web Developer   Egypt
# 3                Tidal                         Dot Net Web Developer   Egypt
# 4           Osolutions                Full Stack wordpress Developer   Egypt
# ...                ...                                           ...     ...
# 2079          Be Group                       Digital Sales Executive   Egypt
# 2080               ITS                         Service Desk Engineer   Egypt
# 2081               ITS                  Quality Assurance Specialist   Egypt
# 2082   FlexFilms Egypt                      IT Help Desk Coordinator   Egypt
# 2083  Arabic Localizer  Software Analyst/Tester (Fresh) - Alexandria   Egypt
#
#             city        district     job_type
# 0     Alexandria            Glim    Full Time
# 1          Cairo            None    Full Time
# 2          Cairo            None    Full Time
# 3          Cairo            None  Shift Based
# 4          Cairo        Sheraton    Full Time
# ...          ...             ...          ...
# 2079       Cairo       Nasr City    Full Time
# 2080       Cairo       Nasr City    Full Time
# 2081       Cairo       Nasr City    Full Time
# 2082        Giza  6th of October    Full Time
# 2083  Alexandria     San Stefano    Full Time
#
# [2084 rows x 6 columns]

# %%
job_posting_category_data.to_csv("job_posting_category.csv", sep=',', encoding='utf-8', index=False)
job_posting_category_data
# Out:
#                company                                     job_title country  \
# 0          Sketch-tech                          Full Stack Developer   Egypt
# 1         Confidential          Senior Backend Developer (.NET Core)   Egypt
# 2         Confidential          Senior Backend Developer (.NET Core)   Egypt
# 3                Tidal                         Dot Net Web Developer   Egypt
# 4                Tidal                         Dot Net Web Developer   Egypt
# ...                ...                                           ...     ...
# 4569   FlexFilms Egypt                      IT Help Desk Coordinator   Egypt
# 4570   FlexFilms Egypt                      IT Help Desk Coordinator   Egypt
# 4571  Arabic Localizer  Software Analyst/Tester (Fresh) - Alexandria   Egypt
# 4572  Arabic Localizer  Software Analyst/Tester (Fresh) - Alexandria   Egypt
# 4573  Arabic Localizer  Software Analyst/Tester (Fresh) - Alexandria   Egypt
#
#             city        district                      job_category
# 0     Alexandria            Glim           IT/Software Development
# 1          Cairo            None           IT/Software Development
# 2          Cairo            None  Engineering - Telecom/Technology
# 3          Cairo            None           IT/Software Development
# 4          Cairo            None  Engineering - Telecom/Technology
# ...          ...             ...                               ...
# 4569        Giza  6th of October   Installation/Maintenance/Repair
# 4570        Giza  6th of October           IT/Software Development
# 4571  Alexandria     San Stefano           IT/Software Development
# 4572  Alexandria     San Stefano                           Quality
# 4573  Alexandria     San Stefano                  Analyst/Research
#
# [4574 rows x 6 columns]

# %%
job_posting_skill_data.to_csv("job_posting_skill.csv", sep =',', encoding ='utf-8', index=False)
job_posting_skill_data
# Out:
#                 company                                     job_title country  \
# 0           Sketch-tech                          Full Stack Developer   Egypt
# 1           Sketch-tech                          Full Stack Developer   Egypt
# 2           Sketch-tech                          Full Stack Developer   Egypt
# 3           Sketch-tech                          Full Stack Developer   Egypt
# 4          Confidential          Senior Backend Developer (.NET Core)   Egypt
# ...                 ...                                           ...     ...
# 23621  Arabic Localizer  Software Analyst/Tester (Fresh) - Alexandria   Egypt
# 23622  Arabic Localizer  Software Analyst/Tester (Fresh) - Alexandria   Egypt
# 23623  Arabic Localizer  Software Analyst/Tester (Fresh) - Alexandria   Egypt
# 23624  Arabic Localizer  Software Analyst/Tester (Fresh) - Alexandria   Egypt
# 23625  Arabic Localizer  Software Analyst/Tester (Fresh) - Alexandria   Egypt
#
#              city     district                        skill
# 0      Alexandria         Glim                   Full Stack
# 1      Alexandria         Glim         Full Stack Developer
# 2      Alexandria         Glim             Computer Science
# 3      Alexandria         Glim         Software Development
# 4           Cairo         None         Software Development
# ...           ...          ...                          ...
# 23621  Alexandria  San Stefano                     Software
# 23622  Alexandria  San Stefano              Quality Control
# 23623  Alexandria  San Stefano  Information Technology (IT)
# 23624  Alexandria  San Stefano             Computer Science
# 23625  Alexandria  San Stefano         Software Development
#
# [23626 rows x 6 columns]

# %%
company_data.to_csv("company.csv", sep=',', encoding='utf-8', index=False)
company_data
# Out:
#                                 company  \
# 0                           Sketch-tech
# 1                                 Tidal
# 2                            Osolutions
# 3                             Safa Soft
# 4          Nahdet Misr Publishing Group
# ..                                  ...
# 690  Advansys for Trading & Contracting
# 691                             URANIUM
# 692                 Dreem Mashreq Foods
# 693                            Be Group
# 694                     FlexFilms Egypt
#
#                                            description country        city  \
# 0                                                 None     NaN         NaN
# 1    Tidal is one of the Software Company. Its main...   Egypt         NaN
# 2    We Help businesses to sell more & more… \n\nAl...   Egypt       Cairo
# 3    Safa Soft.\n\nSafa Soft is a multinational com...   Egypt       Cairo
# 4    Nahdet Misr Publishing House was established b...   Egypt       Cairo
# ..                                                 ...     ...         ...
# 690  Advansys trading and contracting was establish...   Egypt       Cairo
# 691  URANIUM is a Software House company, specializ...   Egypt       Cairo
# 692  Dreem, was founded in the late 70s under the n...   Egypt       Cairo
# 693  Founded in 2009, Be Group has showed a fast gr...   Egypt  Alexandria
# 694  Flex Films is the global film manufacturing ar...   Egypt       Cairo
#
#      found_date size_min size_max
# 0           NaN      NaN      NaN
# 1           NaN      NaN      NaN
# 2    2010-01-01      NaN      NaN
# 3           NaN      NaN      NaN
# 4    2008-01-01      NaN      NaN
# ..          ...      ...      ...
# 690  2006-01-01     None      NaN
# 691  2001-01-01     None      NaN
# 692  2007-01-01     None      NaN
# 693         NaN     None      NaN
# 694  2009-01-01     None      NaN
#
# [695 rows x 7 columns]

# %%
company_sector_data.to_csv("company_sector.csv", sep=',', encoding='utf-8', index=False)
company_sector_data
# Out:
#                  company                           sector
# 0                  Tidal                Computer Software
# 1             Osolutions        Marketing and Advertising
# 2              Safa Soft        Marketing and Advertising
# 3              Safa Soft                Computer Software
# 4              Safa Soft  Information Technology Services
# ..                   ...                              ...
# 754  Dreem Mashreq Foods                             FMCG
# 755             Be Group        Marketing and Advertising
# 756      FlexFilms Egypt                    Manufacturing
# 757      FlexFilms Egypt         Packaging and Containers
# 758      FlexFilms Egypt                         Plastics
#
# [759 rows x 2 columns]

# %%
# %%capture
pip install faker

# %%
from faker import Faker
import random

# %%
faker = Faker()
district_names = ["Downtown", "Uptown", "Central", "West End", "East Side", "Riverside"]

# %%
## user
user_dic = {}
user_data = pd.DataFrame()
for _ in range(500):
    user_dic['email'] = faker.email()
    user_dic['username'] = faker.name()
    user_dic['password'] = faker.password()
    user_dic['country'] = faker.country()
    user_dic['city'] = faker.city() 
    user_dic['district'] = random.choice(district_names)
    user_dic['experience'] = faker.random_int()%17
    user_dic['no_experience'] = random.choice([0, 1])
    user_dic['GPA'] = round(random.uniform(0.0, 4.0), 2)
    user_dic['phone_number'] = faker.phone_number()
    BOD = faker.date_of_birth()
    user_dic['BOD'] = BOD.strftime("%Y, %m, %d")
    user_dic['gender'] = random.choice(['M', 'F'])
    user_dic['first_name'] = faker.first_name()
    user_dic['middle_name'] = faker.last_name()
    user_dic['last_name'] = faker.last_name()
    user_df = pd.DataFrame(user_dic, index=[0])
    user_data = pd.concat([user_data, user_df], ignore_index=True)

# %%
# This is for generating insert statements for user_skill table
email_addresses = user_data.iloc[:, 0]
email_list = email_addresses.tolist()

skills = ['Computer Science', 'Information Technology (IT)', 'Software', 'Software Development', 'Software Engineering']
for email in email_list:
    for skill in skills:
        sql = 'INSERT IGNORE INTO user_skill(email, skill) VALUES("' + email +'", "' + skill +'");'
        print(sql)
# Out:
# INSERT IGNORE INTO user_skill(email, skill) VALUES("michaelhahn@example.com", "Computer Science");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("michaelhahn@example.com", "Information Technology (IT)");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("michaelhahn@example.com", "Software");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("michaelhahn@example.com", "Software Development");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("michaelhahn@example.com", "Software Engineering");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("stephen40@example.org", "Computer Science");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("stephen40@example.org", "Information Technology (IT)");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("stephen40@example.org", "Software");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("stephen40@example.org", "Software Development");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("stephen40@example.org", "Software Engineering");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("rachaelhunt@example.net", "Computer Science");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("rachaelhunt@example.net", "Information Technology (IT)");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("rachaelhunt@example.net", "Software");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("rachaelhunt@example.net", "Software Development");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("rachaelhunt@example.net", "Software Engineering");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("nicholas45@example.com", "Computer Science");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("nicholas45@example.com", "Information Technology (IT)");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("nicholas45@example.com", "Software");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("nicholas45@example.com", "Software Development");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("nicholas45@example.com", "Software Engineering");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("rubioalexander@example.com", "Computer Science");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("rubioalexander@example.com", "Information Technology (IT)");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("rubioalexander@example.com", "Software");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("rubioalexander@example.com", "Software Development");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("rubioalexander@example.com", "Software Engineering");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("handrade@example.com", "Computer Science");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("handrade@example.com", "Information Technology (IT)");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("handrade@example.com", "Software");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("handrade@example.com", "Software Development");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("handrade@example.com", "Software Engineering");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("brandon97@example.org", "Computer Science");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("brandon97@example.org", "Information Technology (IT)");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("brandon97@example.org", "Software");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("brandon97@example.org", "Software Development");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("brandon97@example.org", "Software Engineering");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("wjacobs@example.org", "Computer Science");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("wjacobs@example.org", "Information Technology (IT)");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("wjacobs@example.org", "Software");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("wjacobs@example.org", "Software Development");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("wjacobs@example.org", "Software Engineering");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("laura18@example.net", "Computer Science");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("laura18@example.net", "Information Technology (IT)");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("laura18@example.net", "Software");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("laura18@example.net", "Software Development");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("laura18@example.net", "Software Engineering");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("jmartinez@example.net", "Computer Science");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("jmartinez@example.net", "Information Technology (IT)");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("jmartinez@example.net", "Software");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("jmartinez@example.net", "Software Development");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("jmartinez@example.net", "Software Engineering");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("ograham@example.net", "Computer Science");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("ograham@example.net", "Information Technology (IT)");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("ograham@example.net", "Software");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("ograham@example.net", "Software Development");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("ograham@example.net", "Software Engineering");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("ddominguez@example.net", "Computer Science");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("ddominguez@example.net", "Information Technology (IT)");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("ddominguez@example.net", "Software");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("ddominguez@example.net", "Software Development");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("ddominguez@example.net", "Software Engineering");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("angelasims@example.com", "Computer Science");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("angelasims@example.com", "Information Technology (IT)");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("angelasims@example.com", "Software");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("angelasims@example.com", "Software Development");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("angelasims@example.com", "Software Engineering");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("jordan54@example.net", "Computer Science");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("jordan54@example.net", "Information Technology (IT)");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("jordan54@example.net", "Software");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("jordan54@example.net", "Software Development");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("jordan54@example.net", "Software Engineering");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("allendiana@example.com", "Computer Science");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("allendiana@example.com", "Information Technology (IT)");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("allendiana@example.com", "Software");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("allendiana@example.com", "Software Development");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("allendiana@example.com", "Software Engineering");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("rcross@example.org", "Computer Science");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("rcross@example.org", "Information Technology (IT)");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("rcross@example.org", "Software");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("rcross@example.org", "Software Development");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("rcross@example.org", "Software Engineering");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("bgoodman@example.com", "Computer Science");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("bgoodman@example.com", "Information Technology (IT)");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("bgoodman@example.com", "Software");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("bgoodman@example.com", "Software Development");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("bgoodman@example.com", "Software Engineering");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("shawn12@example.org", "Computer Science");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("shawn12@example.org", "Information Technology (IT)");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("shawn12@example.org", "Software");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("shawn12@example.org", "Software Development");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("shawn12@example.org", "Software Engineering");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("hchen@example.com", "Computer Science");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("hchen@example.com", "Information Technology (IT)");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("hchen@example.com", "Software");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("hchen@example.com", "Software Development");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("hchen@example.com", "Software Engineering");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("pamelajohnson@example.net", "Computer Science");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("pamelajohnson@example.net", "Information Technology (IT)");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("pamelajohnson@example.net", "Software");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("pamelajohnson@example.net", "Software Development");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("pamelajohnson@example.net", "Software Engineering");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("alexisanderson@example.net", "Computer Science");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("alexisanderson@example.net", "Information Technology (IT)");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("alexisanderson@example.net", "Software");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("alexisanderson@example.net", "Software Development");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("alexisanderson@example.net", "Software Engineering");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("erica72@example.com", "Computer Science");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("erica72@example.com", "Information Technology (IT)");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("erica72@example.com", "Software");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("erica72@example.com", "Software Development");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("erica72@example.com", "Software Engineering");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("ian09@example.net", "Computer Science");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("ian09@example.net", "Information Technology (IT)");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("ian09@example.net", "Software");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("ian09@example.net", "Software Development");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("ian09@example.net", "Software Engineering");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("brittanyatkinson@example.org", "Computer Science");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("brittanyatkinson@example.org", "Information Technology (IT)");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("brittanyatkinson@example.org", "Software");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("brittanyatkinson@example.org", "Software Development");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("brittanyatkinson@example.org", "Software Engineering");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("cbell@example.net", "Computer Science");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("cbell@example.net", "Information Technology (IT)");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("cbell@example.net", "Software");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("cbell@example.net", "Software Development");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("cbell@example.net", "Software Engineering");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("castroamy@example.net", "Computer Science");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("castroamy@example.net", "Information Technology (IT)");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("castroamy@example.net", "Software");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("castroamy@example.net", "Software Development");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("castroamy@example.net", "Software Engineering");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("ocrawford@example.org", "Computer Science");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("ocrawford@example.org", "Information Technology (IT)");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("ocrawford@example.org", "Software");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("ocrawford@example.org", "Software Development");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("ocrawford@example.org", "Software Engineering");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("james06@example.net", "Computer Science");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("james06@example.net", "Information Technology (IT)");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("james06@example.net", "Software");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("james06@example.net", "Software Development");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("james06@example.net", "Software Engineering");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("ryan71@example.org", "Computer Science");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("ryan71@example.org", "Information Technology (IT)");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("ryan71@example.org", "Software");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("ryan71@example.org", "Software Development");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("ryan71@example.org", "Software Engineering");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("whitakereric@example.org", "Computer Science");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("whitakereric@example.org", "Information Technology (IT)");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("whitakereric@example.org", "Software");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("whitakereric@example.org", "Software Development");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("whitakereric@example.org", "Software Engineering");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("orodriguez@example.org", "Computer Science");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("orodriguez@example.org", "Information Technology (IT)");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("orodriguez@example.org", "Software");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("orodriguez@example.org", "Software Development");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("orodriguez@example.org", "Software Engineering");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("ufisher@example.net", "Computer Science");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("ufisher@example.net", "Information Technology (IT)");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("ufisher@example.net", "Software");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("ufisher@example.net", "Software Development");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("ufisher@example.net", "Software Engineering");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("michelle26@example.org", "Computer Science");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("michelle26@example.org", "Information Technology (IT)");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("michelle26@example.org", "Software");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("michelle26@example.org", "Software Development");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("michelle26@example.org", "Software Engineering");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("gallagherstephanie@example.com", "Computer Science");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("gallagherstephanie@example.com", "Information Technology (IT)");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("gallagherstephanie@example.com", "Software");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("gallagherstephanie@example.com", "Software Development");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("gallagherstephanie@example.com", "Software Engineering");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("mercadojasmine@example.com", "Computer Science");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("mercadojasmine@example.com", "Information Technology (IT)");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("mercadojasmine@example.com", "Software");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("mercadojasmine@example.com", "Software Development");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("mercadojasmine@example.com", "Software Engineering");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("jensenharry@example.com", "Computer Science");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("jensenharry@example.com", "Information Technology (IT)");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("jensenharry@example.com", "Software");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("jensenharry@example.com", "Software Development");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("jensenharry@example.com", "Software Engineering");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("earl80@example.org", "Computer Science");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("earl80@example.org", "Information Technology (IT)");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("earl80@example.org", "Software");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("earl80@example.org", "Software Development");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("earl80@example.org", "Software Engineering");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("hardyfrances@example.com", "Computer Science");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("hardyfrances@example.com", "Information Technology (IT)");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("hardyfrances@example.com", "Software");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("hardyfrances@example.com", "Software Development");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("hardyfrances@example.com", "Software Engineering");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("crystalwebb@example.net", "Computer Science");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("crystalwebb@example.net", "Information Technology (IT)");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("crystalwebb@example.net", "Software");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("crystalwebb@example.net", "Software Development");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("crystalwebb@example.net", "Software Engineering");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("carl81@example.net", "Computer Science");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("carl81@example.net", "Information Technology (IT)");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("carl81@example.net", "Software");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("carl81@example.net", "Software Development");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("carl81@example.net", "Software Engineering");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("tuckersherri@example.com", "Computer Science");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("tuckersherri@example.com", "Information Technology (IT)");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("tuckersherri@example.com", "Software");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("tuckersherri@example.com", "Software Development");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("tuckersherri@example.com", "Software Engineering");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("yarroyo@example.net", "Computer Science");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("yarroyo@example.net", "Information Technology (IT)");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("yarroyo@example.net", "Software");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("yarroyo@example.net", "Software Development");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("yarroyo@example.net", "Software Engineering");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("crobles@example.com", "Computer Science");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("crobles@example.com", "Information Technology (IT)");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("crobles@example.com", "Software");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("crobles@example.com", "Software Development");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("crobles@example.com", "Software Engineering");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("darryl35@example.org", "Computer Science");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("darryl35@example.org", "Information Technology (IT)");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("darryl35@example.org", "Software");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("darryl35@example.org", "Software Development");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("darryl35@example.org", "Software Engineering");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("stephen30@example.com", "Computer Science");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("stephen30@example.com", "Information Technology (IT)");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("stephen30@example.com", "Software");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("stephen30@example.com", "Software Development");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("stephen30@example.com", "Software Engineering");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("meganfisher@example.net", "Computer Science");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("meganfisher@example.net", "Information Technology (IT)");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("meganfisher@example.net", "Software");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("meganfisher@example.net", "Software Development");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("meganfisher@example.net", "Software Engineering");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("qstark@example.net", "Computer Science");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("qstark@example.net", "Information Technology (IT)");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("qstark@example.net", "Software");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("qstark@example.net", "Software Development");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("qstark@example.net", "Software Engineering");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("jonathanholmes@example.org", "Computer Science");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("jonathanholmes@example.org", "Information Technology (IT)");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("jonathanholmes@example.org", "Software");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("jonathanholmes@example.org", "Software Development");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("jonathanholmes@example.org", "Software Engineering");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("kelleylogan@example.org", "Computer Science");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("kelleylogan@example.org", "Information Technology (IT)");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("kelleylogan@example.org", "Software");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("kelleylogan@example.org", "Software Development");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("kelleylogan@example.org", "Software Engineering");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("butlermanuel@example.net", "Computer Science");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("butlermanuel@example.net", "Information Technology (IT)");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("butlermanuel@example.net", "Software");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("butlermanuel@example.net", "Software Development");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("butlermanuel@example.net", "Software Engineering");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("ryanjackson@example.org", "Computer Science");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("ryanjackson@example.org", "Information Technology (IT)");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("ryanjackson@example.org", "Software");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("ryanjackson@example.org", "Software Development");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("ryanjackson@example.org", "Software Engineering");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("ihernandez@example.org", "Computer Science");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("ihernandez@example.org", "Information Technology (IT)");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("ihernandez@example.org", "Software");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("ihernandez@example.org", "Software Development");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("ihernandez@example.org", "Software Engineering");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("josephbaker@example.org", "Computer Science");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("josephbaker@example.org", "Information Technology (IT)");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("josephbaker@example.org", "Software");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("josephbaker@example.org", "Software Development");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("josephbaker@example.org", "Software Engineering");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("thompsonnicole@example.com", "Computer Science");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("thompsonnicole@example.com", "Information Technology (IT)");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("thompsonnicole@example.com", "Software");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("thompsonnicole@example.com", "Software Development");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("thompsonnicole@example.com", "Software Engineering");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("froberts@example.net", "Computer Science");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("froberts@example.net", "Information Technology (IT)");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("froberts@example.net", "Software");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("froberts@example.net", "Software Development");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("froberts@example.net", "Software Engineering");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("nataliemorgan@example.com", "Computer Science");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("nataliemorgan@example.com", "Information Technology (IT)");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("nataliemorgan@example.com", "Software");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("nataliemorgan@example.com", "Software Development");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("nataliemorgan@example.com", "Software Engineering");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("amber17@example.com", "Computer Science");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("amber17@example.com", "Information Technology (IT)");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("amber17@example.com", "Software");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("amber17@example.com", "Software Development");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("amber17@example.com", "Software Engineering");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("waltonashley@example.com", "Computer Science");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("waltonashley@example.com", "Information Technology (IT)");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("waltonashley@example.com", "Software");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("waltonashley@example.com", "Software Development");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("waltonashley@example.com", "Software Engineering");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("robersonamanda@example.com", "Computer Science");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("robersonamanda@example.com", "Information Technology (IT)");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("robersonamanda@example.com", "Software");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("robersonamanda@example.com", "Software Development");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("robersonamanda@example.com", "Software Engineering");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("taylor35@example.net", "Computer Science");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("taylor35@example.net", "Information Technology (IT)");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("taylor35@example.net", "Software");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("taylor35@example.net", "Software Development");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("taylor35@example.net", "Software Engineering");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("crystalmcpherson@example.com", "Computer Science");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("crystalmcpherson@example.com", "Information Technology (IT)");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("crystalmcpherson@example.com", "Software");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("crystalmcpherson@example.com", "Software Development");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("crystalmcpherson@example.com", "Software Engineering");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("xrosales@example.com", "Computer Science");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("xrosales@example.com", "Information Technology (IT)");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("xrosales@example.com", "Software");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("xrosales@example.com", "Software Development");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("xrosales@example.com", "Software Engineering");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("chelseagray@example.com", "Computer Science");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("chelseagray@example.com", "Information Technology (IT)");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("chelseagray@example.com", "Software");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("chelseagray@example.com", "Software Development");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("chelseagray@example.com", "Software Engineering");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("ricknolan@example.org", "Computer Science");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("ricknolan@example.org", "Information Technology (IT)");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("ricknolan@example.org", "Software");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("ricknolan@example.org", "Software Development");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("ricknolan@example.org", "Software Engineering");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("ashley31@example.com", "Computer Science");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("ashley31@example.com", "Information Technology (IT)");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("ashley31@example.com", "Software");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("ashley31@example.com", "Software Development");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("ashley31@example.com", "Software Engineering");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("christianthornton@example.org", "Computer Science");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("christianthornton@example.org", "Information Technology (IT)");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("christianthornton@example.org", "Software");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("christianthornton@example.org", "Software Development");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("christianthornton@example.org", "Software Engineering");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("dustingilmore@example.net", "Computer Science");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("dustingilmore@example.net", "Information Technology (IT)");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("dustingilmore@example.net", "Software");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("dustingilmore@example.net", "Software Development");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("dustingilmore@example.net", "Software Engineering");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("spencejeremy@example.org", "Computer Science");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("spencejeremy@example.org", "Information Technology (IT)");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("spencejeremy@example.org", "Software");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("spencejeremy@example.org", "Software Development");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("spencejeremy@example.org", "Software Engineering");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("pearsonjohn@example.net", "Computer Science");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("pearsonjohn@example.net", "Information Technology (IT)");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("pearsonjohn@example.net", "Software");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("pearsonjohn@example.net", "Software Development");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("pearsonjohn@example.net", "Software Engineering");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("alan51@example.org", "Computer Science");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("alan51@example.org", "Information Technology (IT)");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("alan51@example.org", "Software");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("alan51@example.org", "Software Development");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("alan51@example.org", "Software Engineering");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("rlam@example.org", "Computer Science");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("rlam@example.org", "Information Technology (IT)");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("rlam@example.org", "Software");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("rlam@example.org", "Software Development");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("rlam@example.org", "Software Engineering");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("gtaylor@example.com", "Computer Science");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("gtaylor@example.com", "Information Technology (IT)");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("gtaylor@example.com", "Software");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("gtaylor@example.com", "Software Development");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("gtaylor@example.com", "Software Engineering");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("ericlee@example.net", "Computer Science");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("ericlee@example.net", "Information Technology (IT)");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("ericlee@example.net", "Software");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("ericlee@example.net", "Software Development");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("ericlee@example.net", "Software Engineering");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("contrerasshannon@example.net", "Computer Science");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("contrerasshannon@example.net", "Information Technology (IT)");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("contrerasshannon@example.net", "Software");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("contrerasshannon@example.net", "Software Development");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("contrerasshannon@example.net", "Software Engineering");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("bradley34@example.org", "Computer Science");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("bradley34@example.org", "Information Technology (IT)");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("bradley34@example.org", "Software");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("bradley34@example.org", "Software Development");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("bradley34@example.org", "Software Engineering");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("cardenaswilliam@example.org", "Computer Science");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("cardenaswilliam@example.org", "Information Technology (IT)");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("cardenaswilliam@example.org", "Software");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("cardenaswilliam@example.org", "Software Development");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("cardenaswilliam@example.org", "Software Engineering");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("stephanieturner@example.org", "Computer Science");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("stephanieturner@example.org", "Information Technology (IT)");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("stephanieturner@example.org", "Software");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("stephanieturner@example.org", "Software Development");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("stephanieturner@example.org", "Software Engineering");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("hbridges@example.com", "Computer Science");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("hbridges@example.com", "Information Technology (IT)");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("hbridges@example.com", "Software");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("hbridges@example.com", "Software Development");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("hbridges@example.com", "Software Engineering");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("bmorris@example.net", "Computer Science");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("bmorris@example.net", "Information Technology (IT)");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("bmorris@example.net", "Software");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("bmorris@example.net", "Software Development");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("bmorris@example.net", "Software Engineering");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("mark68@example.com", "Computer Science");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("mark68@example.com", "Information Technology (IT)");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("mark68@example.com", "Software");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("mark68@example.com", "Software Development");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("mark68@example.com", "Software Engineering");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("monicaschmitt@example.com", "Computer Science");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("monicaschmitt@example.com", "Information Technology (IT)");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("monicaschmitt@example.com", "Software");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("monicaschmitt@example.com", "Software Development");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("monicaschmitt@example.com", "Software Engineering");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("nwatson@example.com", "Computer Science");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("nwatson@example.com", "Information Technology (IT)");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("nwatson@example.com", "Software");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("nwatson@example.com", "Software Development");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("nwatson@example.com", "Software Engineering");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("robertarmstrong@example.net", "Computer Science");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("robertarmstrong@example.net", "Information Technology (IT)");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("robertarmstrong@example.net", "Software");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("robertarmstrong@example.net", "Software Development");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("robertarmstrong@example.net", "Software Engineering");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("qkelly@example.org", "Computer Science");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("qkelly@example.org", "Information Technology (IT)");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("qkelly@example.org", "Software");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("qkelly@example.org", "Software Development");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("qkelly@example.org", "Software Engineering");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("carlosharvey@example.net", "Computer Science");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("carlosharvey@example.net", "Information Technology (IT)");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("carlosharvey@example.net", "Software");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("carlosharvey@example.net", "Software Development");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("carlosharvey@example.net", "Software Engineering");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("dfox@example.org", "Computer Science");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("dfox@example.org", "Information Technology (IT)");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("dfox@example.org", "Software");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("dfox@example.org", "Software Development");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("dfox@example.org", "Software Engineering");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("tguerrero@example.org", "Computer Science");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("tguerrero@example.org", "Information Technology (IT)");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("tguerrero@example.org", "Software");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("tguerrero@example.org", "Software Development");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("tguerrero@example.org", "Software Engineering");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("vrogers@example.org", "Computer Science");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("vrogers@example.org", "Information Technology (IT)");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("vrogers@example.org", "Software");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("vrogers@example.org", "Software Development");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("vrogers@example.org", "Software Engineering");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("garciabrenda@example.net", "Computer Science");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("garciabrenda@example.net", "Information Technology (IT)");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("garciabrenda@example.net", "Software");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("garciabrenda@example.net", "Software Development");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("garciabrenda@example.net", "Software Engineering");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("janicemelendez@example.com", "Computer Science");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("janicemelendez@example.com", "Information Technology (IT)");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("janicemelendez@example.com", "Software");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("janicemelendez@example.com", "Software Development");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("janicemelendez@example.com", "Software Engineering");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("josephmurphy@example.net", "Computer Science");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("josephmurphy@example.net", "Information Technology (IT)");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("josephmurphy@example.net", "Software");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("josephmurphy@example.net", "Software Development");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("josephmurphy@example.net", "Software Engineering");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("larryedwards@example.org", "Computer Science");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("larryedwards@example.org", "Information Technology (IT)");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("larryedwards@example.org", "Software");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("larryedwards@example.org", "Software Development");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("larryedwards@example.org", "Software Engineering");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("mitchelljeffrey@example.com", "Computer Science");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("mitchelljeffrey@example.com", "Information Technology (IT)");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("mitchelljeffrey@example.com", "Software");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("mitchelljeffrey@example.com", "Software Development");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("mitchelljeffrey@example.com", "Software Engineering");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("taylornathan@example.net", "Computer Science");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("taylornathan@example.net", "Information Technology (IT)");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("taylornathan@example.net", "Software");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("taylornathan@example.net", "Software Development");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("taylornathan@example.net", "Software Engineering");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("rperez@example.org", "Computer Science");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("rperez@example.org", "Information Technology (IT)");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("rperez@example.org", "Software");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("rperez@example.org", "Software Development");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("rperez@example.org", "Software Engineering");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("ddiaz@example.net", "Computer Science");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("ddiaz@example.net", "Information Technology (IT)");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("ddiaz@example.net", "Software");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("ddiaz@example.net", "Software Development");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("ddiaz@example.net", "Software Engineering");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("bbailey@example.net", "Computer Science");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("bbailey@example.net", "Information Technology (IT)");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("bbailey@example.net", "Software");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("bbailey@example.net", "Software Development");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("bbailey@example.net", "Software Engineering");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("michaelsmith@example.org", "Computer Science");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("michaelsmith@example.org", "Information Technology (IT)");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("michaelsmith@example.org", "Software");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("michaelsmith@example.org", "Software Development");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("michaelsmith@example.org", "Software Engineering");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("kevin48@example.org", "Computer Science");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("kevin48@example.org", "Information Technology (IT)");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("kevin48@example.org", "Software");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("kevin48@example.org", "Software Development");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("kevin48@example.org", "Software Engineering");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("rachelhayden@example.org", "Computer Science");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("rachelhayden@example.org", "Information Technology (IT)");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("rachelhayden@example.org", "Software");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("rachelhayden@example.org", "Software Development");
# INSERT IGNORE INTO user_skill(email, skill) VALUES("rachelhayden@example.org", "Software Engineering");

# %%
user_data.to_csv('user.csv', sep =',', encoding ='utf-8', index=False)
user_data
# Out:
#                            email          username    password  \
# 0        austinjesse@example.net   Colleen Vaughan  dm25GYGf@)
# 1         onealjesse@example.org    Steven Carlson  Scd1FzfO)i
# 2        tylerwatson@example.org        Dylan Rios  ZEVvBvaJ)9
# 3         patellaura@example.org      Jeremy Welch  (O6aT!TcdA
# 4         tinabarron@example.com  Charles Gonzalez  (E1XjAlx4$
# ..                           ...               ...         ...
# 495         daniel48@example.com       Troy Cooper  o_1QQjhiTz
# 496        laurabond@example.com    Jessica Harris  $7HbygAnEQ
# 497    feliciamiller@example.com    Michael Knight  #+jz0gKbf)
# 498  shannonmichelle@example.net        Shawn Cole  $1KTc*v8Pl
# 499        tracyruiz@example.net     Kenneth Moore  dLDuM7No#c
#
#                     country            city   district  experience  \
# 0                   Ecuador  Lake Jamesberg   Downtown           6
# 1              Saudi Arabia     South Keith    Central          11
# 2          French Polynesia    South Johnny     Uptown          15
# 3                    Jersey    Romanchester   Downtown          11
# 4              Burkina Faso  Lake Davidberg     Uptown           3
# ..                      ...             ...        ...         ...
# 495             El Salvador      Weberville   Downtown           1
# 496                  Guinea     South Jacob  East Side          11
# 497           Liechtenstein    Vanessamouth     Uptown           2
# 498                 Eritrea    Mitchellfurt  Riverside           5
# 499  British Virgin Islands      Nicolestad  Riverside          15
#
#      no_experience   GPA           phone_number           BOD gender  \
# 0                1  3.53           929.395.5255  1945, 09, 27      F
# 1                0  1.06        +1-585-634-4686  1980, 12, 30      F
# 2                0  1.56    +1-483-250-1802x168  1984, 02, 27      F
# 3                0  3.17     387-342-6374x40705  1945, 05, 01      F
# 4                0  3.61      278-702-6607x3389  1999, 05, 27      M
# ..             ...   ...                    ...           ...    ...
# 495              1  1.98             9729361280  2001, 09, 15      F
# 496              0  1.89   +1-454-367-7366x3394  1919, 04, 28      M
# 497              0  3.25        +1-983-670-5781  1954, 07, 07      M
# 498              1  3.42  001-958-833-2365x5677  2023, 08, 06      F
# 499              0  2.29             3237945626  1950, 04, 25      M
#
#     first_name middle_name last_name
# 0     Nicholas       Ochoa  Williams
# 1      Douglas       Johns     Weber
# 2        Jesus      Henson       Lee
# 3       Albert      Warren   Collins
# 4     Danielle      Morris   Vincent
# ..         ...         ...       ...
# 495      Scott    Mcdowell   Barrett
# 496     Nathan         Lee     Silva
# 497     Alicia      Foster    Bowman
# 498       Juan       Glass    Peters
# 499      Scott      Patton    Cooper
#
# [500 rows x 15 columns]

# %%
user_skill_data.to_csv('user_skill.csv', sep =',', encoding ='utf-8', index=False)
user_skill_data
# Out:
#                           skill                       email
# 0              Computer Science     michaelhahn@example.com
# 1          Software Engineering       stephen40@example.org
# 2          Software Engineering     rachaelhunt@example.net
# 3          Software Engineering      nicholas45@example.com
# 4              Computer Science  rubioalexander@example.com
# ..                          ...                         ...
# 95         Software Development           ddiaz@example.net
# 96                     Software         bbailey@example.net
# 97                     Software    michaelsmith@example.org
# 98  Information Technology (IT)         kevin48@example.org
# 99             Computer Science    rachelhayden@example.org
#
# [100 rows x 2 columns]
